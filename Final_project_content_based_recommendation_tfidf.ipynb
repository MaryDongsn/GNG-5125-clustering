# %% [markdown]
# <a href="https://colab.research.google.com/github/MaryDongsn/GNG-5125-clustering/blob/master/Final_project_content_based_recommendation_tfidf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import sqrt
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
###### Use the following code if you use google colab #####
from google.colab import drive 
drive.mount('/content/gdrive')
ratings=pd.read_csv('/content/gdrive/My Drive/gng5125 project/ratings.csv',sep=',', encoding='latin-1', usecols=['userId','movieId','rating','timestamp'])
movies = pd.read_csv('/content/gdrive/My Drive/gng5125 project/movies.csv', sep=',', encoding='latin-1', usecols=['movieId','title','genres'])
# Out:
# Mounted at /content/gdrive

# %%
# # Reading ratings file
# ratings = pd.read_csv('ratings.csv', sep=',', encoding='latin-1', usecols=['userId','movieId','rating','timestamp'])

# # Reading movies file
# movies = pd.read_csv('movies.csv', sep=',', encoding='latin-1', usecols=['movieId','title','genres'])

df_movies = movies 
df_ratings = ratings

# %%
# Define a TF-IDF Vectorizer Object.
tfidf_movies_genres = TfidfVectorizer(token_pattern = '[a-zA-Z0-9\-]+')

#Replace NaN with an empty string
df_movies['genres'] = df_movies['genres'].replace(to_replace="(no genres listed)", value="")

#Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_movies_genres_matrix = tfidf_movies_genres.fit_transform(df_movies['genres'])

# Compute the cosine similarity matrix

cosine_sim_movies = linear_kernel(tfidf_movies_genres_matrix, tfidf_movies_genres_matrix)
# print(cosine_sim_movies)

# %%
def get_recommendations_based_on_genres(movie_title, cosine_sim_movies=cosine_sim_movies):
    """
    Calculates top 2 movies to recommend based on given movie titles genres. 
    :param movie_title: title of movie to be taken for base of recommendation
    :param cosine_sim_movies: cosine similarity between movies 
    :return: Titles of movies recommended to user
    """
    # Get the index of the movie that matches the title
    idx_movie = df_movies.loc[df_movies['title'].isin([movie_title])]
    idx_movie = idx_movie.index
    
    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores_movies = list(enumerate(cosine_sim_movies[idx_movie][0]))
    
    # Sort the movies based on the similarity scores
    sim_scores_movies = sorted(sim_scores_movies, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies 
    sim_scores_movies = sim_scores_movies[0:10]

    
    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores_movies ]
   
    
    # Return the top 10 most similar movies
    return df_movies['title'].iloc[movie_indices]

# %%
get_recommendations_based_on_genres("Toy Story 2 (1999)")
# Out:
# 0                                        Toy Story (1995)
# 1706                                          Antz (1998)
# 2355                                   Toy Story 2 (1999)
# 2809       Adventures of Rocky and Bullwinkle, The (2000)
# 3000                     Emperor's New Groove, The (2000)
# 3568                                Monsters, Inc. (2001)
# 6194                                     Wild, The (2006)
# 6486                               Shrek the Third (2007)
# 6948                       Tale of Despereaux, The (2008)
# 7760    Asterix and the Vikings (AstÃ©rix et les Vikin...
# Name: title, dtype: object

# %%
from sklearn.neighbors import KNeighborsClassifier  
def get_movie_label(movie_id):
    """
    Get the cluster label to which movie belongs by KNN algorithm.  
    :param movie_id: movie id
    :return: genres label to movie belong
    """
    classifier = KNeighborsClassifier(n_neighbors=5)
    x= tfidf_movies_genres_matrix
    y = df_movies.iloc[:,-1]
    classifier.fit(x, y)
    y_pred = classifier.predict(tfidf_movies_genres_matrix[movie_id])
    #movie_name = df_movies['title'].iloc[movie_id]

    #print ("+++++++++",type(y_pred))
    #dic = {'movie_name': movie_name, 'predected_genre': y_pred}
    # apply pandas data frame
    #df_predicted_movie = pd.DataFrame(dic)
    #return (df_predicted_movie)
    return y_pred

# %%
# get_movie_label(2355)

# %%
def get_recommendation_content_model(userId):
    """
    Calculates top movies to be recommended to user based on movie user has watched.  
    :param userId: userid of user
    :return: Titles of movies recommended to user
    """
    recommended_movie_list = []
    movie_list = []
    df_rating_filtered = df_ratings[df_ratings["userId"]== userId]
    for key, row in df_rating_filtered.iterrows():
        movie_list.append((df_movies["title"][row["movieId"]==df_movies["movieId"]]).values) 
    for index, movie in enumerate(movie_list):
        for key, movie_recommended in get_recommendations_based_on_genres(movie[0]).iteritems():
            recommended_movie_list.append(movie_recommended)

    # removing already watched movie from recommended list    
    for movie_title in recommended_movie_list:
        if movie_title in movie_list:
            recommended_movie_list.remove(movie_title)
    
    return set(recommended_movie_list)
#get_recommendation_content_model(1)
#print(type(get_recommendation_content_model(1)))

# %%
true_count = 0
false_count = 0
def evaluate_content_based_model():
    """
    Evaluate content based model.  
    """
    for key, colums in df_movies.iterrows():
        movies_recommended_by_model = get_recommendations_based_on_genres(colums["title"])
        #print(movies_recommended_by_model)
        #print(type(movies_recommended_by_model))
        
        for index, value in movies_recommended_by_model.items():
          
          predicted_genres  = get_movie_label(index)
          
          #print (type(predicted_genres))
          # full_list = (movies_recommended_by_model,predicted_genres)
          # print (full_list)
          #print(predicted_genres)
          for predicted_genre in predicted_genres:
              global true_count, false_count
              if predicted_genre == colums["genres"]:
                true_count = true_count+1
              else:
                print("movie_name: ",value)
                print("Actual Genres: ", colums["genres"])
                
                # print(colums["genres"])
                print("Pridicted as:  ", predicted_genre)

                
                false_count = false_count +1
evaluate_content_based_model()
total = true_count + false_count
print("Hit:"+ str(true_count/total))
print("Fault:" + str(false_count/total))
# Out:
# Streaming output truncated to the last 5000 lines.
# Actual Genres:  Action|Animation|Children|Comedy|Musical
# Pridicted as:   Animation|Children|Comedy|Musical
# movie_name:  All Dogs Christmas Carol, An (1998)
# Actual Genres:  Action|Animation|Children|Comedy|Musical
# Pridicted as:   Animation|Children|Comedy|Musical
# movie_name:  Winnie the Pooh and the Blustery Day (1968)
# Actual Genres:  Action|Animation|Children|Comedy|Musical
# Pridicted as:   Animation|Children|Musical
# movie_name:  Three Caballeros, The (1945)
# Actual Genres:  Action|Animation|Children|Comedy|Musical
# Pridicted as:   Animation|Children|Musical
# movie_name:  Cats Don't Dance (1997)
# Actual Genres:  Action|Animation|Children|Comedy|Musical
# Pridicted as:   Animation|Children|Musical
# movie_name:  Dragon Ball: The Curse Of The Blood Rubies (Doragon bÃ´ru: Shenron no densetsu) (1986)
# Actual Genres:  Action|Adventure|Animation|Children|Comedy
# Pridicted as:   Action|Adventure|Animation|Children
# movie_name:  Dragon Ball: Sleeping Princess in Devil's Castle (Doragon bÃ´ru: MajinjÃ´ no nemuri hime) (1987)
# Actual Genres:  Action|Adventure|Animation|Children|Comedy
# Pridicted as:   Action|Adventure|Animation|Children
# movie_name:  Dragon Ball: Mystical Adventure (Doragon bÃ´ru: Makafushigi dai bÃ´ken) (1988)
# Actual Genres:  Action|Adventure|Animation|Children|Comedy
# Pridicted as:   Action|Adventure|Animation|Children
# movie_name:  Brave (2012)
# Actual Genres:  Action|Adventure|Animation|Children|Comedy
# Pridicted as:   Action|Adventure|Animation|Children
# movie_name:  Dragon Ball: The Path to Power (Doragon bÃ´ru: SaikyÃ´ e no michi) (1996)
# Actual Genres:  Action|Adventure|Animation|Children|Comedy
# Pridicted as:   Action|Adventure|Animation|Children
# movie_name:  Maleficent (2014)
# Actual Genres:  Action|Adventure|Children|IMAX
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|IMAX
# movie_name:  Madagascar: Escape 2 Africa (2008)
# Actual Genres:  Action|Adventure|Children|IMAX
# Pridicted as:   Adventure|Animation|Children|Comedy|IMAX
# movie_name:  Kung Fu Panda 2 (2011)
# Actual Genres:  Action|Adventure|Children|IMAX
# Pridicted as:   Adventure|Animation|Children|Comedy|IMAX
# movie_name:  Speed Racer (2008)
# Actual Genres:  Action|Adventure|Children|IMAX
# Pridicted as:   Action|Sci-Fi|IMAX
# movie_name:  Spiderwick Chronicles, The (2008)
# Actual Genres:  Action|Adventure|Children|IMAX
# Pridicted as:   Adventure|Children|Drama|Fantasy|IMAX
# movie_name:  Where the Wild Things Are (2009)
# Actual Genres:  Action|Adventure|Children|IMAX
# Pridicted as:   Adventure|Children|Drama|Fantasy|IMAX
# movie_name:  Mars Needs Moms (2011)
# Actual Genres:  Action|Adventure|Children|IMAX
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|IMAX
# movie_name:  Charlie and the Chocolate Factory (2005)
# Actual Genres:  Action|Adventure|Children|IMAX
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy|IMAX
# movie_name:  Poseidon (2006)
# Actual Genres:  Action|Adventure|Children|IMAX
# Pridicted as:   Action|Adventure|Thriller|IMAX
# movie_name:  Mission: Impossible - Ghost Protocol (2011)
# Actual Genres:  Action|Adventure|Children|IMAX
# Pridicted as:   Action|Adventure|Thriller|IMAX
# movie_name:  Jaws (1975)
# Actual Genres:  Action|Comedy|Horror
# Pridicted as:   Action|Horror
# movie_name:  Jaws 3-D (1983)
# Actual Genres:  Action|Comedy|Horror
# Pridicted as:   Action|Horror
# movie_name:  Crow: Salvation, The (2000)
# Actual Genres:  Action|Comedy|Horror
# Pridicted as:   Action|Horror
# movie_name:  Dog Soldiers (2002)
# Actual Genres:  Action|Comedy|Horror
# Pridicted as:   Action|Horror
# movie_name:  V for Vendetta (2006)
# Actual Genres:  Action|Sci-Fi|IMAX
# Pridicted as:   Action|Sci-Fi|Thriller|IMAX
# movie_name:  Transformers (2007)
# Actual Genres:  Action|Sci-Fi|IMAX
# Pridicted as:   Action|Sci-Fi|Thriller|IMAX
# movie_name:  I Am Number Four (2011)
# Actual Genres:  Action|Sci-Fi|IMAX
# Pridicted as:   Action|Sci-Fi|Thriller|IMAX
# movie_name:  Battleship (2012)
# Actual Genres:  Action|Sci-Fi|IMAX
# Pridicted as:   Action|Sci-Fi|Thriller|IMAX
# movie_name:  Tangled Ever After (2012)
# Actual Genres:  Action|Animation|Children
# Pridicted as:   Action|Animation|Children|Comedy
# movie_name:  Powerpuff Girls, The (2002)
# Actual Genres:  Action|Animation|Children
# Pridicted as:   Action|Animation|Children|Comedy
# movie_name:  Kung Fu Panda: Secrets of the Furious Five (2008)
# Actual Genres:  Action|Animation|Children
# Pridicted as:   Action|Animation|Children|Comedy
# movie_name:  Captain Underpants: The First Epic Movie (2017)
# Actual Genres:  Action|Animation|Children
# Pridicted as:   Action|Animation|Children|Comedy
# movie_name:  Swan Princess, The (1994)
# Actual Genres:  Action|Animation|Children
# Pridicted as:   Animation|Children
# movie_name:  Aristocats, The (1970)
# Actual Genres:  Action|Animation|Children
# Pridicted as:   Animation|Children
# movie_name:  Charlotte's Web (1973)
# Actual Genres:  Action|Animation|Children
# Pridicted as:   Animation|Children
# movie_name:  King and I, The (1999)
# Actual Genres:  Action|Animation|Children
# Pridicted as:   Animation|Children
# movie_name:  Doug's 1st Movie (1999)
# Actual Genres:  Action|Animation|Children
# Pridicted as:   Animation|Children
# movie_name:  Batman: Mask of the Phantasm (1993)
# Actual Genres:  Action|Animation|Children
# Pridicted as:   Animation|Children
# movie_name:  Manhattan Murder Mystery (1993)
# Actual Genres:  Comedy|Drama|Mystery
# Pridicted as:   Comedy|Mystery
# movie_name:  Trouble with Harry, The (1955)
# Actual Genres:  Comedy|Drama|Mystery
# Pridicted as:   Comedy|Mystery
# movie_name:  Outrageous Fortune (1987)
# Actual Genres:  Comedy|Drama|Mystery
# Pridicted as:   Comedy|Mystery
# movie_name:  Who's Harry Crumb? (1989)
# Actual Genres:  Comedy|Drama|Mystery
# Pridicted as:   Comedy|Mystery
# movie_name:  Private Eyes, The (1981)
# Actual Genres:  Comedy|Drama|Mystery
# Pridicted as:   Comedy|Mystery
# movie_name:  Colourful (Karafuru) (2010)
# Actual Genres:  Animation|Drama|Fantasy|Mystery
# Pridicted as:   Animation|Fantasy|Mystery
# movie_name:  Alice (Neco z Alenky) (1988)
# Actual Genres:  Animation|Drama|Fantasy|Mystery
# Pridicted as:   Animation|Fantasy|Mystery
# movie_name:  Kizumonogatari II: Passionate Blood (2016)
# Actual Genres:  Animation|Drama|Fantasy|Mystery
# Pridicted as:   Animation|Fantasy|Mystery
# movie_name:  Kizumonogatari III: Cold Blood (2017)
# Actual Genres:  Animation|Drama|Fantasy|Mystery
# Pridicted as:   Animation|Fantasy|Mystery
# movie_name:  Blue Exorcist: The Movie (2012)
# Actual Genres:  Animation|Drama|Fantasy|Mystery
# Pridicted as:   Animation|Fantasy|Mystery
# movie_name:  Monster House (2006)
# Actual Genres:  Animation|Drama|Fantasy|Mystery
# Pridicted as:   Animation|Fantasy|Mystery
# movie_name:  Fanny and Alexander (Fanny och Alexander) (1982)
# Actual Genres:  Animation|Drama|Fantasy|Mystery
# Pridicted as:   Drama|Fantasy|Mystery
# movie_name:  Lady in the Water (2006)
# Actual Genres:  Animation|Drama|Fantasy|Mystery
# Pridicted as:   Drama|Fantasy|Mystery
# movie_name:  Winter's Tale (2014)
# Actual Genres:  Animation|Drama|Fantasy|Mystery
# Pridicted as:   Drama|Fantasy|Mystery
# movie_name:  Waking Life (2001)
# Actual Genres:  Animation|Drama|Fantasy|Mystery
# Pridicted as:   Animation|Drama|Fantasy
# movie_name:  Mummy, The (1932)
# Actual Genres:  Comedy|Horror|Romance
# Pridicted as:   Horror|Romance
# movie_name:  Dracula (1979)
# Actual Genres:  Comedy|Horror|Romance
# Pridicted as:   Horror|Romance
# movie_name:  Squirm (1976)
# Actual Genres:  Comedy|Horror|Romance
# Pridicted as:   Horror|Romance
# movie_name:  American Werewolf in Paris, An (1997)
# Actual Genres:  Comedy|Horror|Romance
# Pridicted as:   Comedy|Horror|Romance|Thriller
# movie_name:  Batman: Assault on Arkham (2014)
# Actual Genres:  Action|Animation|Crime|Thriller
# Pridicted as:   Action|Animation|Crime
# movie_name:  Batman: Gotham Knight (2008)
# Actual Genres:  Action|Animation|Crime|Thriller
# Pridicted as:   Action|Animation|Crime
# movie_name:  Batman: Year One (2011)
# Actual Genres:  Action|Animation|Crime|Thriller
# Pridicted as:   Action|Animation|Crime
# movie_name:  The Professional: Golgo 13 (1983)
# Actual Genres:  Action|Animation|Crime|Thriller
# Pridicted as:   Action|Animation|Crime
# movie_name:  Batman Beyond: Return of the Joker (2000)
# Actual Genres:  Action|Animation|Crime|Thriller
# Pridicted as:   Action|Animation|Crime|Sci-Fi|Thriller
# movie_name:  Ghost in the Shell: Solid State Society (2006)
# Actual Genres:  Action|Animation|Crime|Thriller
# Pridicted as:   Action|Animation|Crime|Sci-Fi|Thriller
# movie_name:  Batman: The Killing Joke (2016)
# Actual Genres:  Action|Animation|Crime|Thriller
# Pridicted as:   Action|Animation|Crime
# movie_name:  Osmosis Jones (2001)
# Actual Genres:  Action|Animation|Crime|Thriller
# Pridicted as:   Action|Crime|Romance|Thriller
# movie_name:  Heat (1995)
# Actual Genres:  Action|Animation|Crime|Thriller
# Pridicted as:   Action|Crime|Thriller
# movie_name:  Assassins (1995)
# Actual Genres:  Action|Animation|Crime|Thriller
# Pridicted as:   Action|Crime|Thriller
# movie_name:  Soylent Green (1973)
# Actual Genres:  Drama|Mystery|Sci-Fi
# Pridicted as:   Drama|Mystery|Sci-Fi|Thriller
# movie_name:  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# Actual Genres:  Drama|Mystery|Sci-Fi|Thriller
# Pridicted as:   Mystery|Sci-Fi|Thriller
# movie_name:  Unforgettable (1996)
# Actual Genres:  Drama|Mystery|Sci-Fi|Thriller
# Pridicted as:   Mystery|Sci-Fi|Thriller
# movie_name:  20,000 Days on Earth (2014)
# Actual Genres:  Documentary|Drama|Musical
# Pridicted as:   Documentary|Musical
# movie_name:  Madonna: Truth or Dare (1991)
# Actual Genres:  Documentary|Drama|Musical
# Pridicted as:   Documentary|Musical
# movie_name:  Buena Vista Social Club (1999)
# Actual Genres:  Documentary|Drama|Musical
# Pridicted as:   Documentary|Musical
# movie_name:  Stop Making Sense (1984)
# Actual Genres:  Documentary|Drama|Musical
# Pridicted as:   Documentary|Musical
# movie_name:  U2: Rattle and Hum (1988)
# Actual Genres:  Documentary|Drama|Musical
# Pridicted as:   Documentary|Musical
# movie_name:  Decline of Western Civilization, The (1981)
# Actual Genres:  Documentary|Drama|Musical
# Pridicted as:   Documentary|Musical
# movie_name:  Standing in the Shadows of Motown (2002)
# Actual Genres:  Documentary|Drama|Musical
# Pridicted as:   Documentary|Musical
# movie_name:  Monterey Pop (1968)
# Actual Genres:  Documentary|Drama|Musical
# Pridicted as:   Documentary|Musical
# movie_name:  Sympathy for the Devil (1968)
# Actual Genres:  Documentary|Drama|Musical
# Pridicted as:   Documentary|Musical
# movie_name:  Anvil! The Story of Anvil (2008)
# Actual Genres:  Documentary|Drama|Musical
# Pridicted as:   Documentary|Musical
# movie_name:  Star Trek VI: The Undiscovered Country (1991)
# Actual Genres:  Action|Mystery|Sci-Fi
# Pridicted as:   Action|Mystery|Sci-Fi|Thriller
# movie_name:  Maze Runner, The (2014)
# Actual Genres:  Action|Mystery|Sci-Fi
# Pridicted as:   Action|Mystery|Sci-Fi|Thriller
# movie_name:  Cloverfield (2008)
# Actual Genres:  Action|Mystery|Sci-Fi
# Pridicted as:   Action|Mystery|Sci-Fi|Thriller
# movie_name:  Predestination (2014)
# Actual Genres:  Action|Mystery|Sci-Fi
# Pridicted as:   Action|Mystery|Sci-Fi|Thriller
# movie_name:  Self/less (2015)
# Actual Genres:  Action|Mystery|Sci-Fi
# Pridicted as:   Action|Mystery|Sci-Fi|Thriller
# movie_name:  Maze Runner: The Death Cure (2018)
# Actual Genres:  Action|Mystery|Sci-Fi
# Pridicted as:   Action|Mystery|Sci-Fi|Thriller
# movie_name:  Andromeda Strain, The (1971)
# Actual Genres:  Action|Mystery|Sci-Fi
# Pridicted as:   Drama|Mystery|Sci-Fi
# movie_name:  Project X (1968)
# Actual Genres:  Action|Mystery|Sci-Fi
# Pridicted as:   Drama|Mystery|Sci-Fi
# movie_name:  Knowing (2009)
# Actual Genres:  Action|Mystery|Sci-Fi
# Pridicted as:   Action|Mystery|Sci-Fi|Thriller
# movie_name:  Negotiator, The (1998)
# Actual Genres:  Action|Crime|Mystery|Thriller
# Pridicted as:   Action|Crime|Drama|Mystery|Thriller
# movie_name:  Insomnia (2002)
# Actual Genres:  Action|Crime|Mystery|Thriller
# Pridicted as:   Action|Crime|Drama|Mystery|Thriller
# movie_name:  Man on Fire (2004)
# Actual Genres:  Action|Crime|Mystery|Thriller
# Pridicted as:   Action|Crime|Drama|Mystery|Thriller
# movie_name:  Toy Story (1995)
# Actual Genres:
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Jumanji (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Father of the Bride Part II (1995)
# Actual Genres:
# Pridicted as:   Comedy
# movie_name:  Heat (1995)
# Actual Genres:
# Pridicted as:   Action|Crime|Thriller
# movie_name:  Sabrina (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Tom and Huck (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children
# movie_name:  Sudden Death (1995)
# Actual Genres:
# Pridicted as:   Action
# movie_name:  GoldenEye (1995)
# Actual Genres:
# Pridicted as:   Action|Adventure|Thriller
# movie_name:  Fire and Ice (1983)
# Actual Genres:  Animation|Drama|Fantasy
# Pridicted as:   Animation|Fantasy
# movie_name:  Secret of Kells, The (2009)
# Actual Genres:  Animation|Drama|Fantasy
# Pridicted as:   Animation|Fantasy
# movie_name:  Sintel (2010)
# Actual Genres:  Animation|Drama|Fantasy
# Pridicted as:   Animation|Fantasy
# movie_name:  Fire and Ice (1983)
# Actual Genres:  Animation|Drama|Fantasy
# Pridicted as:   Animation|Fantasy
# movie_name:  Secret of Kells, The (2009)
# Actual Genres:  Animation|Drama|Fantasy
# Pridicted as:   Animation|Fantasy
# movie_name:  Sintel (2010)
# Actual Genres:  Animation|Drama|Fantasy
# Pridicted as:   Animation|Fantasy
# movie_name:  Dracula: Dead and Loving It (1995)
# Actual Genres:  Comedy|Drama|Horror
# Pridicted as:   Comedy|Horror
# movie_name:  Tales from the Crypt Presents: Bordello of Blood (1996)
# Actual Genres:  Comedy|Drama|Horror
# Pridicted as:   Comedy|Horror
# movie_name:  Gremlins (1984)
# Actual Genres:  Comedy|Drama|Horror
# Pridicted as:   Comedy|Horror
# movie_name:  Gremlins 2: The New Batch (1990)
# Actual Genres:  Comedy|Drama|Horror
# Pridicted as:   Comedy|Horror
# movie_name:  Attack of the Killer Tomatoes! (1978)
# Actual Genres:  Comedy|Drama|Horror
# Pridicted as:   Comedy|Horror
# movie_name:  Mystery Men (1999)
# Actual Genres:  Action|Drama|Fantasy
# Pridicted as:   Action|Comedy|Fantasy
# movie_name:  R.I.P.D. (2013)
# Actual Genres:  Action|Drama|Fantasy
# Pridicted as:   Action|Comedy|Fantasy
# movie_name:  Lord of the Rings: The Return of the King, The (2003)
# Actual Genres:  Action|Drama|Fantasy
# Pridicted as:   Action|Adventure|Drama|Fantasy
# movie_name:  Beowulf & Grendel (2005)
# Actual Genres:  Action|Drama|Fantasy
# Pridicted as:   Action|Adventure|Drama|Fantasy
# movie_name:  Seeker: The Dark Is Rising, The (2007)
# Actual Genres:  Action|Drama|Fantasy
# Pridicted as:   Action|Adventure|Drama|Fantasy
# movie_name:  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# Actual Genres:  Action|Mystery|Sci-Fi|Thriller
# Pridicted as:   Mystery|Sci-Fi|Thriller
# movie_name:  Unforgettable (1996)
# Actual Genres:  Action|Mystery|Sci-Fi|Thriller
# Pridicted as:   Mystery|Sci-Fi|Thriller
# movie_name:  Justin and the Knights of Valour (2013)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Drama
# movie_name:  The Rabbi's Cat (Le chat du rabbin) (2011)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Drama
# movie_name:  Tokyo Godfathers (2003)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Drama
# movie_name:  Sky Crawlers, The (Sukai kurora) (2008)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Drama
# movie_name:  Over the Garden Wall (2013)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Drama
# movie_name:  Wallace & Gromit: The Best of Aardman Animation (1996)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Comedy
# movie_name:  Family Guy Presents Stewie Griffin: The Untold Story (2005)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Comedy
# movie_name:  Ice Age 4: Continental Drift (2012)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Comedy
# movie_name:  ParaNorman (2012)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Comedy
# movie_name:  Croods, The (2013)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Comedy
# movie_name:  Mezzo Forte (1998)
# Actual Genres:  Action|Animation|Comedy|Horror
# Pridicted as:   Action|Animation|Comedy
# movie_name:  Big Hero 6 (2014)
# Actual Genres:  Action|Animation|Comedy|Horror
# Pridicted as:   Action|Animation|Comedy
# movie_name:  Gintama: The Final Chapter - Be Forever Yorozuya (2013)
# Actual Genres:  Action|Animation|Comedy|Horror
# Pridicted as:   Action|Animation|Comedy
# movie_name:  The Lego Batman Movie (2017)
# Actual Genres:  Action|Animation|Comedy|Horror
# Pridicted as:   Action|Animation|Comedy
# movie_name:  Watchmen: Tales of the Black Freighter (2009)
# Actual Genres:  Action|Animation|Comedy|Horror
# Pridicted as:   Action|Adventure|Animation
# movie_name:  Buffy the Vampire Slayer (1992)
# Actual Genres:  Action|Animation|Comedy|Horror
# Pridicted as:   Action|Comedy|Horror
# movie_name:  Street Fighter II: The Animated Movie (SutorÃ®to FaitÃ¢ II gekijÃ´-ban) (1994)
# Actual Genres:  Action|Animation|Comedy
# Pridicted as:   Action|Animation
# movie_name:  Batman: Under the Red Hood (2010)
# Actual Genres:  Action|Animation|Comedy
# Pridicted as:   Action|Animation
# movie_name:  Superman/Doomsday (2007)
# Actual Genres:  Action|Animation|Comedy
# Pridicted as:   Action|Animation
# movie_name:  Batman: The Dark Knight Returns, Part 2 (2013)
# Actual Genres:  Action|Animation|Comedy
# Pridicted as:   Action|Animation
# movie_name:  Mortal Kombat: The Journey Begins (1995)
# Actual Genres:  Action|Animation|Comedy
# Pridicted as:   Action|Animation
# movie_name:  Bungo Stray Dogs: Dead Apple (2018)
# Actual Genres:  Action|Animation|Comedy
# Pridicted as:   Action|Animation
# movie_name:  The Book of Life (2014)
# Actual Genres:  Adventure|Animation|Romance
# Pridicted as:   Adventure|Animation
# movie_name:  Justin and the Knights of Valour (2013)
# Actual Genres:  Adventure|Animation|Romance
# Pridicted as:   Adventure|Animation|Drama
# movie_name:  The Rabbi's Cat (Le chat du rabbin) (2011)
# Actual Genres:  Adventure|Animation|Romance
# Pridicted as:   Adventure|Animation|Drama
# movie_name:  Howl's Moving Castle (Hauru no ugoku shiro) (2004)
# Actual Genres:  Adventure|Animation|Romance
# Pridicted as:   Adventure|Animation|Fantasy
# movie_name:  Garden of Words, The (Koto no ha no niwa) (2013)
# Actual Genres:  Adventure|Animation|Romance
# Pridicted as:   Animation|Drama|Romance
# movie_name:  The Night Is Short, Walk on Girl (2017)
# Actual Genres:  Adventure|Animation|Romance
# Pridicted as:   Animation|Drama|Romance
# movie_name:  Porco Rosso (Crimson Pig) (Kurenai no buta) (1992)
# Actual Genres:  Adventure|Animation|Romance
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy|Romance
# movie_name:  Tokyo Godfathers (2003)
# Actual Genres:  Adventure|Animation|Romance
# Pridicted as:   Adventure|Animation|Drama
# movie_name:  Sky Crawlers, The (Sukai kurora) (2008)
# Actual Genres:  Adventure|Animation|Romance
# Pridicted as:   Adventure|Animation|Drama
# movie_name:  Over the Garden Wall (2013)
# Actual Genres:  Adventure|Animation|Romance
# Pridicted as:   Adventure|Animation|Drama
# movie_name:  RoboCop 3 (1993)
# Actual Genres:  Crime|Drama|Sci-Fi|Thriller
# Pridicted as:   Action|Crime|Drama|Sci-Fi|Thriller
# movie_name:  RoboCop (1987)
# Actual Genres:  Crime|Drama|Sci-Fi|Thriller
# Pridicted as:   Action|Crime|Drama|Sci-Fi|Thriller
# movie_name:  RoboCop 2 (1990)
# Actual Genres:  Crime|Drama|Sci-Fi|Thriller
# Pridicted as:   Action|Crime|Drama|Sci-Fi|Thriller
# movie_name:  Day the Earth Stood Still, The (1951)
# Actual Genres:  Crime|Drama|Sci-Fi|Thriller
# Pridicted as:   Drama|Sci-Fi|Thriller
# movie_name:  Gattaca (1997)
# Actual Genres:  Crime|Drama|Sci-Fi|Thriller
# Pridicted as:   Drama|Sci-Fi|Thriller
# movie_name:  Transformers: Dark of the Moon (2011)
# Actual Genres:  Action|Drama|War|IMAX
# Pridicted as:   Action|Adventure|Sci-Fi|IMAX
# movie_name:  Grandmaster, The (Yi dai zong shi) (2013)
# Actual Genres:  Action|Drama|War|IMAX
# Pridicted as:   Action|Drama|Thriller|IMAX
# movie_name:  Man of Tai Chi (2013)
# Actual Genres:  Action|Drama|War|IMAX
# Pridicted as:   Action|Comedy|IMAX
# movie_name:  White House Down (2013)
# Actual Genres:  Action|Drama|War|IMAX
# Pridicted as:   Action|Drama|Thriller|IMAX
# movie_name:  Jack Ryan: Shadow Recruit (2014)
# Actual Genres:  Action|Drama|War|IMAX
# Pridicted as:   Action|Drama|Thriller|IMAX
# movie_name:  Night at the Museum: Battle of the Smithsonian (2009)
# Actual Genres:  Action|Drama|War|IMAX
# Pridicted as:   Action|Comedy|Fantasy|IMAX
# movie_name:  Dark Knight, The (2008)
# Actual Genres:  Action|Drama|War|IMAX
# Pridicted as:   Action|Crime|Drama|IMAX
# movie_name:  Jaws (1975)
# Actual Genres:  Action|Comedy|Horror
# Pridicted as:   Action|Horror
# movie_name:  Jaws 3-D (1983)
# Actual Genres:  Action|Comedy|Horror
# Pridicted as:   Action|Horror
# movie_name:  Crow: Salvation, The (2000)
# Actual Genres:  Action|Comedy|Horror
# Pridicted as:   Action|Horror
# movie_name:  Dog Soldiers (2002)
# Actual Genres:  Action|Comedy|Horror
# Pridicted as:   Action|Horror
# movie_name:  Great Yokai War, The (YÃ´kai daisensÃ´) (2005)
# Actual Genres:  Adventure|Comedy|Horror
# Pridicted as:   Comedy|Fantasy|Horror
# movie_name:  Mega Shark vs. Crocosaurus (2010)
# Actual Genres:  Adventure|Comedy|Horror
# Pridicted as:   Action|Adventure|Horror|Sci-Fi
# movie_name:  Dracula: Dead and Loving It (1995)
# Actual Genres:  Adventure|Comedy|Horror
# Pridicted as:   Comedy|Horror
# movie_name:  Tales from the Crypt Presents: Bordello of Blood (1996)
# Actual Genres:  Adventure|Comedy|Horror
# Pridicted as:   Comedy|Horror
# movie_name:  Control (Kontroll) (2003)
# Actual Genres:  Comedy|Crime|Drama|Mystery|Romance
# Pridicted as:   Comedy|Crime|Mystery
# movie_name:  Gentlemen of Fortune (Dzhentlmeny udachi) (1972)
# Actual Genres:  Comedy|Crime|Drama|Mystery|Romance
# Pridicted as:   Comedy|Crime|Mystery
# movie_name:  Charade (1963)
# Actual Genres:  Comedy|Crime|Drama|Mystery|Romance
# Pridicted as:   Crime|Drama|Mystery|Romance|Thriller
# movie_name:  Daytrippers, The (1996)
# Actual Genres:  Comedy|Crime|Drama|Mystery|Romance
# Pridicted as:   Comedy|Mystery|Romance
# movie_name:  Palmetto (1998)
# Actual Genres:  Comedy|Crime|Drama|Mystery|Romance
# Pridicted as:   Crime|Drama|Mystery|Romance|Thriller
# movie_name:  Jurassic Park (1993)
# Actual Genres:  Adventure|Sci-Fi|Thriller
# Pridicted as:   Action|Adventure|Sci-Fi|Thriller
# movie_name:  Independence Day (a.k.a. ID4) (1996)
# Actual Genres:  Adventure|Sci-Fi|Thriller
# Pridicted as:   Action|Adventure|Sci-Fi|Thriller
# movie_name:  Escape from L.A. (1996)
# Actual Genres:  Adventure|Sci-Fi|Thriller
# Pridicted as:   Action|Adventure|Sci-Fi|Thriller
# movie_name:  Abyss, The (1989)
# Actual Genres:  Adventure|Sci-Fi|Thriller
# Pridicted as:   Action|Adventure|Sci-Fi|Thriller
# movie_name:  Another Stakeout (1993)
# Actual Genres:  Comedy|Drama|Thriller
# Pridicted as:   Comedy|Thriller
# movie_name:  Jetsons: The Movie (1990)
# Actual Genres:  Animation|Children|Comedy|Musical|Sci-Fi
# Pridicted as:   Animation|Children|Comedy|Musical
# movie_name:  Jungle Book, The (1967)
# Actual Genres:  Animation|Children|Comedy|Musical|Sci-Fi
# Pridicted as:   Animation|Children|Comedy|Musical
# movie_name:  Steamboat Willie (1928)
# Actual Genres:  Animation|Children|Comedy|Musical|Sci-Fi
# Pridicted as:   Animation|Children|Comedy|Musical
# movie_name:  Ferngully: The Last Rainforest (1992)
# Actual Genres:  Animation|Children|Comedy|Musical|Sci-Fi
# Pridicted as:   Animation|Children|Comedy|Musical
# movie_name:  Claymation Christmas Celebration, A (1987)
# Actual Genres:  Animation|Children|Comedy|Musical|Sci-Fi
# Pridicted as:   Animation|Children|Comedy|Musical
# movie_name:  Alvin and the Chipmunks: The Squeakquel (2009)
# Actual Genres:  Animation|Children|Comedy|Musical|Sci-Fi
# Pridicted as:   Animation|Children|Comedy|Musical
# movie_name:  All Dogs Christmas Carol, An (1998)
# Actual Genres:  Animation|Children|Comedy|Musical|Sci-Fi
# Pridicted as:   Animation|Children|Comedy|Musical
# movie_name:  Winnie the Pooh and the Blustery Day (1968)
# Actual Genres:  Animation|Children|Comedy|Musical|Sci-Fi
# Pridicted as:   Animation|Children|Musical
# movie_name:  Three Caballeros, The (1945)
# Actual Genres:  Animation|Children|Comedy|Musical|Sci-Fi
# Pridicted as:   Animation|Children|Musical
# movie_name:  Cats Don't Dance (1997)
# Actual Genres:  Animation|Children|Comedy|Musical|Sci-Fi
# Pridicted as:   Animation|Children|Musical
# movie_name:  Partly Cloudy (2009)
# Actual Genres:  Animation|Children|Fantasy
# Pridicted as:   Animation|Children|Comedy|Fantasy
# movie_name:  Presto (2008)
# Actual Genres:  Animation|Children|Fantasy
# Pridicted as:   Animation|Children|Comedy|Fantasy
# movie_name:  Cloudy with a Chance of Meatballs 2 (2013)
# Actual Genres:  Animation|Children|Fantasy
# Pridicted as:   Animation|Children|Comedy|Fantasy
# movie_name:  Jurassic Park (1993)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi|Thriller
# Pridicted as:   Action|Adventure|Sci-Fi|Thriller
# movie_name:  Independence Day (a.k.a. ID4) (1996)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi|Thriller
# Pridicted as:   Action|Adventure|Sci-Fi|Thriller
# movie_name:  Escape from L.A. (1996)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi|Thriller
# Pridicted as:   Action|Adventure|Sci-Fi|Thriller
# movie_name:  Grosse Pointe Blank (1997)
# Actual Genres:  Action|Comedy|Crime|Romance
# Pridicted as:   Comedy|Crime|Romance
# movie_name:  Heartbreakers (2001)
# Actual Genres:  Action|Comedy|Crime|Romance
# Pridicted as:   Comedy|Crime|Romance
# movie_name:  Harlem Nights (1989)
# Actual Genres:  Action|Comedy|Crime|Romance
# Pridicted as:   Comedy|Crime|Romance
# movie_name:  Bandits (2001)
# Actual Genres:  Action|Comedy|Crime|Romance
# Pridicted as:   Comedy|Crime|Romance
# movie_name:  Legal Eagles (1986)
# Actual Genres:  Action|Comedy|Crime|Romance
# Pridicted as:   Comedy|Crime|Romance
# movie_name:  Gigli (2003)
# Actual Genres:  Action|Comedy|Crime|Romance
# Pridicted as:   Comedy|Crime|Romance
# movie_name:  How to Steal a Million (1966)
# Actual Genres:  Action|Comedy|Crime|Romance
# Pridicted as:   Comedy|Crime|Romance
# movie_name:  Dragonheart 2: A New Beginning (2000)
# Actual Genres:  Action|Adventure|Comedy|Drama|Fantasy|Thriller
# Pridicted as:   Action|Adventure|Drama|Fantasy|Thriller
# movie_name:  Mighty Joe Young (1998)
# Actual Genres:  Action|Adventure|Comedy|Drama|Fantasy|Thriller
# Pridicted as:   Action|Adventure|Fantasy|Thriller
# movie_name:  King Kong (2005)
# Actual Genres:  Action|Adventure|Comedy|Drama|Fantasy|Thriller
# Pridicted as:   Action|Adventure|Fantasy|Thriller
# movie_name:  Batman & Robin (1997)
# Actual Genres:  Action|Adventure|Comedy|Drama|Fantasy|Thriller
# Pridicted as:   Action|Adventure|Fantasy|Thriller
# movie_name:  The Scorpion King (2002)
# Actual Genres:  Action|Adventure|Comedy|Drama|Fantasy|Thriller
# Pridicted as:   Action|Adventure|Fantasy|Thriller
# movie_name:  Mummy: Tomb of the Dragon Emperor, The (2008)
# Actual Genres:  Action|Adventure|Comedy|Drama|Fantasy|Thriller
# Pridicted as:   Action|Adventure|Fantasy|Thriller
# movie_name:  Crow, The: Wicked Prayer (2005)
# Actual Genres:  Action|Adventure|Comedy|Drama|Fantasy|Thriller
# Pridicted as:   Action|Adventure|Fantasy|Thriller
# movie_name:  Last Action Hero (1993)
# Actual Genres:  Action|Adventure|Comedy|Drama|Fantasy|Thriller
# Pridicted as:   Action|Adventure|Comedy|Fantasy
# movie_name:  Big Trouble in Little China (1986)
# Actual Genres:  Action|Adventure|Comedy|Drama|Fantasy|Thriller
# Pridicted as:   Action|Adventure|Comedy|Fantasy
# movie_name:  Dungeons & Dragons (2000)
# Actual Genres:  Action|Adventure|Comedy|Drama|Fantasy|Thriller
# Pridicted as:   Action|Adventure|Comedy|Fantasy
# movie_name:  Peacemaker, The (1997)
# Actual Genres:  Action|Drama|Thriller|War
# Pridicted as:   Action|Thriller|War
# movie_name:  Justin and the Knights of Valour (2013)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Drama
# movie_name:  The Rabbi's Cat (Le chat du rabbin) (2011)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Drama
# movie_name:  Tokyo Godfathers (2003)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Drama
# movie_name:  Sky Crawlers, The (Sukai kurora) (2008)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Drama
# movie_name:  Over the Garden Wall (2013)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Drama
# movie_name:  Wallace & Gromit: The Best of Aardman Animation (1996)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Comedy
# movie_name:  Family Guy Presents Stewie Griffin: The Untold Story (2005)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Comedy
# movie_name:  Ice Age 4: Continental Drift (2012)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Comedy
# movie_name:  ParaNorman (2012)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Comedy
# movie_name:  Croods, The (2013)
# Actual Genres:  Adventure|Animation
# Pridicted as:   Adventure|Animation|Comedy
# movie_name:  The Green Prince (2014)
# Actual Genres:  Documentary|Drama|Thriller
# Pridicted as:   Documentary|Drama
# movie_name:  From the Earth to the Moon (1998)
# Actual Genres:  Documentary|Drama|Thriller
# Pridicted as:   Action|Comedy|Documentary
# movie_name:  Looking for Richard (1996)
# Actual Genres:  Documentary|Drama|Thriller
# Pridicted as:   Documentary|Drama
# movie_name:  On the Ropes (1999)
# Actual Genres:  Documentary|Drama|Thriller
# Pridicted as:   Documentary|Drama
# movie_name:  Rude Boy (1980)
# Actual Genres:  Documentary|Drama|Thriller
# Pridicted as:   Documentary|Drama
# movie_name:  Pirates of Silicon Valley (1999)
# Actual Genres:  Documentary|Drama|Thriller
# Pridicted as:   Documentary|Drama
# movie_name:  Titicut Follies (1967)
# Actual Genres:  Documentary|Drama|Thriller
# Pridicted as:   Documentary|Drama
# movie_name:  Story of the Weeping Camel, The (Geschichte vom weinenden Kamel, Die) (2003)
# Actual Genres:  Documentary|Drama|Thriller
# Pridicted as:   Documentary|Drama
# movie_name:  Jesus Camp (2006)
# Actual Genres:  Documentary|Drama|Thriller
# Pridicted as:   Documentary|Drama
# movie_name:  Sicko (2007)
# Actual Genres:  Documentary|Drama|Thriller
# Pridicted as:   Documentary|Drama
# movie_name:  Black Sea (2015)
# Actual Genres:  Adventure|Mystery|Thriller
# Pridicted as:   Action|Adventure|Mystery|Thriller
# movie_name:  Man Who Knew Too Much, The (1956)
# Actual Genres:  Adventure|Mystery|Thriller
# Pridicted as:   Action|Adventure|Drama|Mystery|Thriller
# movie_name:  Mission: Impossible (1996)
# Actual Genres:  Adventure|Mystery|Thriller
# Pridicted as:   Action|Adventure|Drama|Mystery|Thriller
# movie_name:  Hanna (2011)
# Actual Genres:  Adventure|Mystery|Thriller
# Pridicted as:   Action|Adventure|Drama|Mystery|Thriller
# movie_name:  National Treasure (2004)
# Actual Genres:  Adventure|Mystery|Thriller
# Pridicted as:   Action|Adventure|Drama|Mystery|Thriller
# movie_name:  Bourne Identity, The (1988)
# Actual Genres:  Adventure|Mystery|Thriller
# Pridicted as:   Action|Adventure|Drama|Mystery|Thriller
# movie_name:  Losers, The (2010)
# Actual Genres:  Adventure|Mystery|Thriller
# Pridicted as:   Action|Adventure|Drama|Mystery|Thriller
# movie_name:  Annihilation (2018)
# Actual Genres:  Adventure|Mystery|Thriller
# Pridicted as:   Mystery|Sci-Fi|Thriller
# movie_name:  Seven (a.k.a. Se7en) (1995)
# Actual Genres:  Adventure|Mystery|Thriller
# Pridicted as:   Mystery|Thriller
# movie_name:  Just Cause (1995)
# Actual Genres:  Adventure|Mystery|Thriller
# Pridicted as:   Mystery|Thriller
# movie_name:  Girl Walks Home Alone at Night, A (2014)
# Actual Genres:  Horror|Romance|Thriller
# Pridicted as:   Comedy|Horror|Romance|Thriller
# movie_name:  Wolf (1994)
# Actual Genres:  Horror|Romance|Thriller
# Pridicted as:   Comedy|Horror|Romance|Thriller
# movie_name:  Cat People (1942)
# Actual Genres:  Horror|Romance|Thriller
# Pridicted as:   Comedy|Horror|Romance|Thriller
# movie_name:  American Werewolf in Paris, An (1997)
# Actual Genres:  Horror|Romance|Thriller
# Pridicted as:   Comedy|Horror|Romance|Thriller
# movie_name:  Pride and Prejudice and Zombies (2016)
# Actual Genres:  Horror|Romance|Thriller
# Pridicted as:   Comedy|Horror|Romance|Thriller
# movie_name:  Mummy, The (1932)
# Actual Genres:  Horror|Romance|Thriller
# Pridicted as:   Horror|Romance
# movie_name:  Dracula (1979)
# Actual Genres:  Horror|Romance|Thriller
# Pridicted as:   Horror|Romance
# movie_name:  Squirm (1976)
# Actual Genres:  Horror|Romance|Thriller
# Pridicted as:   Horror|Romance
# movie_name:  Relative Fear (1994)
# Actual Genres:  Horror|Romance|Thriller
# Pridicted as:   Horror|Thriller
# movie_name:  Tales from the Crypt Presents: Demon Knight (1995)
# Actual Genres:  Horror|Romance|Thriller
# Pridicted as:   Horror|Thriller
# movie_name:  Scooby-Doo! Abracadabra-Doo (2010)
# Actual Genres:  Animation|Children|Mystery
# Pridicted as:   Animation|Children
# movie_name:  Monster House (2006)
# Actual Genres:  Animation|Children|Mystery
# Pridicted as:   Animation|Fantasy|Mystery
# movie_name:  Swan Princess, The (1994)
# Actual Genres:  Animation|Children|Mystery
# Pridicted as:   Animation|Children
# movie_name:  Aristocats, The (1970)
# Actual Genres:  Animation|Children|Mystery
# Pridicted as:   Animation|Children
# movie_name:  Charlotte's Web (1973)
# Actual Genres:  Animation|Children|Mystery
# Pridicted as:   Animation|Children
# movie_name:  King and I, The (1999)
# Actual Genres:  Animation|Children|Mystery
# Pridicted as:   Animation|Children
# movie_name:  Doug's 1st Movie (1999)
# Actual Genres:  Animation|Children|Mystery
# Pridicted as:   Animation|Children
# movie_name:  Batman: Mask of the Phantasm (1993)
# Actual Genres:  Animation|Children|Mystery
# Pridicted as:   Animation|Children
# movie_name:  Tigger Movie, The (2000)
# Actual Genres:  Animation|Children|Mystery
# Pridicted as:   Animation|Children
# movie_name:  Road to El Dorado, The (2000)
# Actual Genres:  Animation|Children|Mystery
# Pridicted as:   Animation|Children
# movie_name:  Babes in Toyland (1961)
# Actual Genres:  Children|Comedy|Fantasy|Musical
# Pridicted as:   Children|Fantasy|Musical
# movie_name:  5,000 Fingers of Dr. T, The (1953)
# Actual Genres:  Children|Comedy|Fantasy|Musical
# Pridicted as:   Children|Fantasy|Musical
# movie_name:  Peter Pan (1960)
# Actual Genres:  Children|Comedy|Fantasy|Musical
# Pridicted as:   Children|Fantasy|Musical
# movie_name:  Wiz, The (1978)
# Actual Genres:  Children|Comedy|Fantasy|Musical
# Pridicted as:   Adventure|Children|Comedy|Fantasy|Musical
# movie_name:  Chitty Chitty Bang Bang (1968)
# Actual Genres:  Children|Comedy|Fantasy|Musical
# Pridicted as:   Adventure|Children|Comedy|Fantasy|Musical
# movie_name:  Cinderella (1997)
# Actual Genres:  Children|Comedy|Fantasy|Musical
# Pridicted as:   Children|Fantasy|Musical
# movie_name:  Tombstone (1993)
# Actual Genres:  Action|Drama|Thriller|Western
# Pridicted as:   Action|Drama|Western
# movie_name:  Once Upon a Time in the West (C'era una volta il West) (1968)
# Actual Genres:  Action|Drama|Thriller|Western
# Pridicted as:   Action|Drama|Western
# movie_name:  Django Unchained (2012)
# Actual Genres:  Action|Drama|Thriller|Western
# Pridicted as:   Action|Drama|Western
# movie_name:  Fire and Ice (1983)
# Actual Genres:  Animation|Drama|Fantasy
# Pridicted as:   Animation|Fantasy
# movie_name:  Secret of Kells, The (2009)
# Actual Genres:  Animation|Drama|Fantasy
# Pridicted as:   Animation|Fantasy
# movie_name:  Sintel (2010)
# Actual Genres:  Animation|Drama|Fantasy
# Pridicted as:   Animation|Fantasy
# movie_name:  PK (2014)
# Actual Genres:  Comedy|Drama|Fantasy|Mystery|Romance
# Pridicted as:   Drama|Fantasy|Mystery|Romance
# movie_name:  Practical Magic (1998)
# Actual Genres:  Comedy|Drama|Fantasy|Mystery|Romance
# Pridicted as:   Drama|Fantasy|Mystery|Romance
# movie_name:  Faraway, So Close (In weiter Ferne, so nah!) (1993)
# Actual Genres:  Comedy|Drama|Fantasy|Mystery|Romance
# Pridicted as:   Drama|Fantasy|Mystery|Romance
# movie_name:  Illusionist, The (2006)
# Actual Genres:  Comedy|Drama|Fantasy|Mystery|Romance
# Pridicted as:   Drama|Fantasy|Mystery|Romance
# movie_name:  Curious Case of Benjamin Button, The (2008)
# Actual Genres:  Comedy|Drama|Fantasy|Mystery|Romance
# Pridicted as:   Drama|Fantasy|Mystery|Romance
# movie_name:  Exterminating Angel, The (Ãngel exterminador, El) (1962)
# Actual Genres:  Comedy|Drama|Fantasy|Mystery|Romance
# Pridicted as:   Drama|Fantasy|Mystery
# movie_name:  Dragonfly (2002)
# Actual Genres:  Comedy|Drama|Fantasy|Mystery|Romance
# Pridicted as:   Drama|Fantasy|Mystery|Romance
# movie_name:  Scoop (2006)
# Actual Genres:  Comedy|Drama|Fantasy|Mystery|Romance
# Pridicted as:   Drama|Fantasy|Mystery
# movie_name:  Fanny and Alexander (Fanny och Alexander) (1982)
# Actual Genres:  Comedy|Drama|Fantasy|Mystery|Romance
# Pridicted as:   Drama|Fantasy|Mystery
# movie_name:  Lady in the Water (2006)
# Actual Genres:  Comedy|Drama|Fantasy|Mystery|Romance
# Pridicted as:   Drama|Fantasy|Mystery
# movie_name:  The Hound of the Baskervilles (1988)
# Actual Genres:  Crime|Drama|Horror|Mystery
# Pridicted as:   Comedy|Crime|Drama|Horror|Mystery
# movie_name:  Opera (1987)
# Actual Genres:  Crime|Drama|Horror|Mystery
# Pridicted as:   Crime|Horror|Mystery|Thriller
# movie_name:  Gozu (GokudÃ´ kyÃ´fu dai-gekijÃ´: Gozu) (2003)
# Actual Genres:  Crime|Drama|Horror|Mystery
# Pridicted as:   Comedy|Crime|Drama|Horror|Mystery
# movie_name:  Copycat (1995)
# Actual Genres:  Crime|Drama|Horror|Mystery
# Pridicted as:   Crime|Horror|Mystery|Thriller
# movie_name:  American Psycho (2000)
# Actual Genres:  Crime|Drama|Horror|Mystery
# Pridicted as:   Crime|Horror|Mystery|Thriller
# movie_name:  Book of Shadows: Blair Witch 2 (2000)
# Actual Genres:  Crime|Drama|Horror|Mystery
# Pridicted as:   Crime|Horror|Mystery|Thriller
# movie_name:  From Hell (2001)
# Actual Genres:  Crime|Drama|Horror|Mystery
# Pridicted as:   Crime|Horror|Mystery|Thriller
# movie_name:  Identity (2003)
# Actual Genres:  Crime|Drama|Horror|Mystery
# Pridicted as:   Crime|Horror|Mystery|Thriller
# movie_name:  House of Wax (1953)
# Actual Genres:  Crime|Drama|Horror|Mystery
# Pridicted as:   Crime|Horror|Mystery|Thriller
# movie_name:  Testament of Dr. Mabuse, The (Das Testament des Dr. Mabuse) (1933)
# Actual Genres:  Crime|Drama|Horror|Mystery
# Pridicted as:   Crime|Horror|Mystery|Thriller
# movie_name:  Super Mario Bros. (1993)
# Actual Genres:  Adventure|Children|Fantasy|Sci-Fi
# Pridicted as:   Action|Adventure|Children|Comedy|Fantasy
# movie_name:  Omen, The (1976)
# Actual Genres:  Comedy|Horror|Mystery|Thriller
# Pridicted as:   Horror|Mystery|Thriller
# movie_name:  I Know What You Did Last Summer (1997)
# Actual Genres:  Comedy|Horror|Mystery|Thriller
# Pridicted as:   Horror|Mystery|Thriller
# movie_name:  Friday the 13th (1980)
# Actual Genres:  Comedy|Horror|Mystery|Thriller
# Pridicted as:   Horror|Mystery|Thriller
# movie_name:  I Still Know What You Did Last Summer (1998)
# Actual Genres:  Comedy|Horror|Mystery|Thriller
# Pridicted as:   Horror|Mystery|Thriller
# movie_name:  Thumbelina (1994)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Animation|Children|Fantasy
# movie_name:  Care Bears Movie, The (1985)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Animation|Children|Fantasy
# movie_name:  Last Unicorn, The (1982)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Animation|Children|Fantasy
# movie_name:  Craft, The (1996)
# Actual Genres:  Fantasy|Horror|Thriller
# Pridicted as:   Drama|Fantasy|Horror|Thriller
# movie_name:  Carrie (1976)
# Actual Genres:  Fantasy|Horror|Thriller
# Pridicted as:   Drama|Fantasy|Horror|Thriller
# movie_name:  Goodnight Mommy (Ich seh ich seh) (2014)
# Actual Genres:  Fantasy|Horror|Thriller
# Pridicted as:   Drama|Fantasy|Horror|Thriller
# movie_name:  Man of Steel (2013)
# Actual Genres:  Action|Adventure|Fantasy|Sci-Fi|IMAX
# Pridicted as:   Action|Adventure|Fantasy|IMAX
# movie_name:  Star Wars: Episode VII - The Force Awakens (2015)
# Actual Genres:  Action|Adventure|Fantasy|Sci-Fi|IMAX
# Pridicted as:   Action|Adventure|Fantasy|IMAX
# movie_name:  Harry Potter and the Deathly Hallows: Part 1 (2010)
# Actual Genres:  Action|Adventure|Fantasy|Sci-Fi|IMAX
# Pridicted as:   Action|Adventure|Fantasy|IMAX
# movie_name:  Pirates of the Caribbean: On Stranger Tides (2011)
# Actual Genres:  Action|Adventure|Fantasy|Sci-Fi|IMAX
# Pridicted as:   Action|Adventure|Fantasy|IMAX
# movie_name:  Wrath of the Titans (2012)
# Actual Genres:  Action|Adventure|Fantasy|Sci-Fi|IMAX
# Pridicted as:   Action|Adventure|Fantasy|IMAX
# movie_name:  Oz the Great and Powerful (2013)
# Actual Genres:  Action|Adventure|Fantasy|Sci-Fi|IMAX
# Pridicted as:   Action|Adventure|Fantasy|IMAX
# movie_name:  Thor: The Dark World (2013)
# Actual Genres:  Action|Adventure|Fantasy|Sci-Fi|IMAX
# Pridicted as:   Action|Adventure|Fantasy|IMAX
# movie_name:  Star Wars: Episode II - Attack of the Clones (2002)
# Actual Genres:  Action|Adventure|Fantasy|Sci-Fi|IMAX
# Pridicted as:   Action|Adventure|Sci-Fi|IMAX
# movie_name:  Spider-Man 2 (2004)
# Actual Genres:  Action|Adventure|Fantasy|Sci-Fi|IMAX
# Pridicted as:   Action|Adventure|Sci-Fi|IMAX
# movie_name:  Toy Story (1995)
# Actual Genres:
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Jumanji (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Father of the Bride Part II (1995)
# Actual Genres:
# Pridicted as:   Comedy
# movie_name:  Heat (1995)
# Actual Genres:
# Pridicted as:   Action|Crime|Thriller
# movie_name:  Sabrina (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Tom and Huck (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children
# movie_name:  Sudden Death (1995)
# Actual Genres:
# Pridicted as:   Action
# movie_name:  GoldenEye (1995)
# Actual Genres:
# Pridicted as:   Action|Adventure|Thriller
# movie_name:  Toy Story (1995)
# Actual Genres:
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Jumanji (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Father of the Bride Part II (1995)
# Actual Genres:
# Pridicted as:   Comedy
# movie_name:  Heat (1995)
# Actual Genres:
# Pridicted as:   Action|Crime|Thriller
# movie_name:  Sabrina (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Tom and Huck (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children
# movie_name:  Sudden Death (1995)
# Actual Genres:
# Pridicted as:   Action
# movie_name:  GoldenEye (1995)
# Actual Genres:
# Pridicted as:   Action|Adventure|Thriller
# movie_name:  Waterworld (1995)
# Actual Genres:  Action|Adventure|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Sci-Fi
# movie_name:  RocketMan (a.k.a. Rocket Man) (1997)
# Actual Genres:  Children|Comedy|Romance
# Pridicted as:   Children|Comedy|Sci-Fi
# movie_name:  It Takes Two (1995)
# Actual Genres:  Children|Comedy|Romance
# Pridicted as:   Children|Comedy
# movie_name:  Big Green, The (1995)
# Actual Genres:  Children|Comedy|Romance
# Pridicted as:   Children|Comedy
# movie_name:  Mortal Kombat (1995)
# Actual Genres:  Action|Adventure|Drama|Fantasy
# Pridicted as:   Action|Adventure|Fantasy
# movie_name:  Street Fighter (1994)
# Actual Genres:  Action|Adventure|Drama|Fantasy
# Pridicted as:   Action|Adventure|Fantasy
# movie_name:  Dragonheart (1996)
# Actual Genres:  Action|Adventure|Drama|Fantasy
# Pridicted as:   Action|Adventure|Fantasy
# movie_name:  Highlander (1986)
# Actual Genres:  Action|Adventure|Drama|Fantasy
# Pridicted as:   Action|Adventure|Fantasy
# movie_name:  Delirium (2014)
# Actual Genres:  Adventure|Romance|Sci-Fi
# Pridicted as:   Adventure|Drama|Romance|Sci-Fi
# movie_name:  Starman (1984)
# Actual Genres:  Adventure|Romance|Sci-Fi
# Pridicted as:   Adventure|Drama|Romance|Sci-Fi
# movie_name:  Passengers (2016)
# Actual Genres:  Adventure|Romance|Sci-Fi
# Pridicted as:   Adventure|Drama|Romance|Sci-Fi
# movie_name:  The Lovers (2015)
# Actual Genres:  Adventure|Romance|Sci-Fi
# Pridicted as:   Action|Adventure|Sci-Fi
# movie_name:  Star Trek: The Motion Picture (1979)
# Actual Genres:  Adventure|Romance|Sci-Fi
# Pridicted as:   Adventure|Sci-Fi
# movie_name:  Dune (1984)
# Actual Genres:  Adventure|Romance|Sci-Fi
# Pridicted as:   Adventure|Sci-Fi
# movie_name:  King Kong Lives (1986)
# Actual Genres:  Adventure|Romance|Sci-Fi
# Pridicted as:   Adventure|Sci-Fi
# movie_name:  My Science Project (1985)
# Actual Genres:  Adventure|Romance|Sci-Fi
# Pridicted as:   Adventure|Sci-Fi
# movie_name:  Baby... Secret of the Lost Legend (1985)
# Actual Genres:  Adventure|Romance|Sci-Fi
# Pridicted as:   Adventure|Sci-Fi
# movie_name:  Voyage to the Bottom of the Sea (1961)
# Actual Genres:  Adventure|Romance|Sci-Fi
# Pridicted as:   Adventure|Sci-Fi
# movie_name:  Waltz with Bashir (Vals im Bashir) (2008)
# Actual Genres:  Animation|Documentary
# Pridicted as:   Documentary|War
# movie_name:  Nico Icon (1995)
# Actual Genres:  Animation|Documentary
# Pridicted as:   Documentary
# movie_name:  Heidi Fleiss: Hollywood Madam (1995)
# Actual Genres:  Animation|Documentary
# Pridicted as:   Documentary
# movie_name:  Catwalk (1996)
# Actual Genres:  Animation|Documentary
# Pridicted as:   Documentary
# movie_name:  Anne Frank Remembered (1995)
# Actual Genres:  Animation|Documentary
# Pridicted as:   Documentary
# movie_name:  Jupiter's Wife (1994)
# Actual Genres:  Animation|Documentary
# Pridicted as:   Documentary
# movie_name:  Man of the Year (1995)
# Actual Genres:  Animation|Documentary
# Pridicted as:   Documentary
# movie_name:  Crumb (1994)
# Actual Genres:  Animation|Documentary
# Pridicted as:   Documentary
# movie_name:  The Beast of Hollow Mountain (1956)
# Actual Genres:  Horror|Sci-Fi|Western
# Pridicted as:   Horror|Western
# movie_name:  The Dark Tower (2017)
# Actual Genres:  Horror|Sci-Fi|Western
# Pridicted as:   Fantasy|Western
# movie_name:  Vampires (1998)
# Actual Genres:  Horror|Sci-Fi|Western
# Pridicted as:   Horror|Western
# movie_name:  Near Dark (1987)
# Actual Genres:  Horror|Sci-Fi|Western
# Pridicted as:   Horror|Western
# movie_name:  Bone Tomahawk (2015)
# Actual Genres:  Horror|Sci-Fi|Western
# Pridicted as:   Horror|Western
# movie_name:  Tremors 4: The Legend Begins (2004)
# Actual Genres:  Horror|Sci-Fi|Western
# Pridicted as:   Action|Comedy|Horror|Sci-Fi|Thriller|Western
# movie_name:  Burrowers, The (2008)
# Actual Genres:  Horror|Sci-Fi|Western
# Pridicted as:   Horror|Western
# movie_name:  Wild Wild West (1999)
# Actual Genres:  Horror|Sci-Fi|Western
# Pridicted as:   Action|Comedy|Western
# movie_name:  Back to the Future Part III (1990)
# Actual Genres:  Horror|Sci-Fi|Western
# Pridicted as:   Adventure|Comedy|Western
# movie_name:  Westworld (1973)
# Actual Genres:  Horror|Sci-Fi|Western
# Pridicted as:   Action|Thriller|Western
# movie_name:  Radioland Murders (1994)
# Actual Genres:  Adventure|Comedy|Mystery|Romance
# Pridicted as:   Comedy|Mystery|Romance
# movie_name:  They Might Be Giants (1971)
# Actual Genres:  Adventure|Comedy|Mystery|Romance
# Pridicted as:   Comedy|Mystery|Romance
# movie_name:  Daytrippers, The (1996)
# Actual Genres:  Adventure|Comedy|Mystery|Romance
# Pridicted as:   Comedy|Mystery|Romance
# movie_name:  North by Northwest (1959)
# Actual Genres:  Adventure|Comedy|Mystery|Romance
# Pridicted as:   Action|Adventure|Drama|Mystery|Thriller
# movie_name:  Saragossa Manuscript, The (Rekopis znaleziony w Saragossie) (1965)
# Actual Genres:  Adventure|Comedy|Mystery|Romance
# Pridicted as:   Adventure|Comedy|Mystery
# movie_name:  Six Days Seven Nights (1998)
# Actual Genres:  Adventure|Comedy|Mystery|Romance
# Pridicted as:   Adventure|Comedy|Romance
# movie_name:  Tom Jones (1963)
# Actual Genres:  Adventure|Comedy|Mystery|Romance
# Pridicted as:   Adventure|Comedy|Romance
# movie_name:  Daytrippers, The (1996)
# Actual Genres:  Drama|Mystery|Romance
# Pridicted as:   Comedy|Mystery|Romance
# movie_name:  Honey, We Shrunk Ourselves (1997)
# Actual Genres:  Action|Adventure|Children|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Sci-Fi
# movie_name:  Solo: A Star Wars Story (2018)
# Actual Genres:  Action|Adventure|Children|Comedy|Sci-Fi
# Pridicted as:   Adventure|Children|Sci-Fi
# ...
# Actual Genres:
# Pridicted as:   Action|Adventure|Thriller
# movie_name:  Mutant Aliens (2001)
# Actual Genres:  Animation|Sci-Fi
# Pridicted as:   Animation|Comedy|Sci-Fi
# movie_name:  Annihilation (2018)
# Actual Genres:  Adventure|Mystery|Sci-Fi|Thriller
# Pridicted as:   Mystery|Sci-Fi|Thriller
# movie_name:  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# Actual Genres:  Adventure|Mystery|Sci-Fi|Thriller
# Pridicted as:   Mystery|Sci-Fi|Thriller
# movie_name:  Unforgettable (1996)
# Actual Genres:  Adventure|Mystery|Sci-Fi|Thriller
# Pridicted as:   Mystery|Sci-Fi|Thriller
# movie_name:  Stepford Wives, The (1975)
# Actual Genres:  Adventure|Mystery|Sci-Fi|Thriller
# Pridicted as:   Mystery|Sci-Fi|Thriller
# movie_name:  Seconds (1966)
# Actual Genres:  Adventure|Mystery|Sci-Fi|Thriller
# Pridicted as:   Mystery|Sci-Fi|Thriller
# movie_name:  District 9 (2009)
# Actual Genres:  Adventure|Mystery|Sci-Fi|Thriller
# Pridicted as:   Mystery|Sci-Fi|Thriller
# movie_name:  Narcopolis (2014)
# Actual Genres:  Adventure|Mystery|Sci-Fi|Thriller
# Pridicted as:   Mystery|Sci-Fi|Thriller
# movie_name:  Black Sea (2015)
# Actual Genres:  Adventure|Mystery|Sci-Fi|Thriller
# Pridicted as:   Action|Adventure|Mystery|Thriller
# movie_name:  Soylent Green (1973)
# Actual Genres:  Adventure|Mystery|Sci-Fi|Thriller
# Pridicted as:   Drama|Mystery|Sci-Fi|Thriller
# movie_name:  Donnie Darko (2001)
# Actual Genres:  Adventure|Mystery|Sci-Fi|Thriller
# Pridicted as:   Drama|Mystery|Sci-Fi|Thriller
# movie_name:  Toy Story (1995)
# Actual Genres:
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Jumanji (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Father of the Bride Part II (1995)
# Actual Genres:
# Pridicted as:   Comedy
# movie_name:  Heat (1995)
# Actual Genres:
# Pridicted as:   Action|Crime|Thriller
# movie_name:  Sabrina (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Tom and Huck (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children
# movie_name:  Sudden Death (1995)
# Actual Genres:
# Pridicted as:   Action
# movie_name:  GoldenEye (1995)
# Actual Genres:
# Pridicted as:   Action|Adventure|Thriller
# movie_name:  The Star Wars Holiday Special (1978)
# Actual Genres:  Children|Comedy|Sci-Fi
# Pridicted as:   Adventure|Children|Sci-Fi
# movie_name:  *batteries not included (1987)
# Actual Genres:  Children|Comedy|Sci-Fi
# Pridicted as:   Action|Children|Comedy|Fantasy|Sci-Fi
# movie_name:  Honey, We Shrunk Ourselves (1997)
# Actual Genres:  Children|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Sci-Fi
# movie_name:  Monday (2000)
# Actual Genres:  Action|Crime|Fantasy
# Pridicted as:   Action|Comedy|Crime|Fantasy
# movie_name:  Hancock (2008)
# Actual Genres:  Action|Crime|Fantasy
# Pridicted as:   Action|Adventure|Comedy|Fantasy
# movie_name:  Highlander III: The Sorcerer (a.k.a. Highlander: The Final Dimension) (1994)
# Actual Genres:  Action|Crime|Fantasy
# Pridicted as:   Action|Drama|Fantasy
# movie_name:  Wizards of the Lost Kingdom II (1989)
# Actual Genres:  Action|Crime|Fantasy
# Pridicted as:   Action|Drama|Fantasy
# movie_name:  Now and Then (1995)
# Actual Genres:  Children
# Pridicted as:   Children|Drama
# movie_name:  Babe (1995)
# Actual Genres:  Children
# Pridicted as:   Children|Drama
# movie_name:  White Balloon, The (Badkonake sefid) (1995)
# Actual Genres:  Children
# Pridicted as:   Children|Drama
# movie_name:  Fluke (1995)
# Actual Genres:  Children
# Pridicted as:   Children|Drama
# movie_name:  Little Princess, A (1995)
# Actual Genres:  Children
# Pridicted as:   Children|Drama
# movie_name:  Secret Garden, The (1993)
# Actual Genres:  Children
# Pridicted as:   Children|Drama
# movie_name:  Game Night (2018)
# Actual Genres:  Action|Comedy|Crime|Horror
# Pridicted as:   Action|Crime|Horror
# movie_name:  Tales from the Hood (1995)
# Actual Genres:  Action|Comedy|Crime|Horror
# Pridicted as:   Action|Crime|Horror
# movie_name:  Darkman II: Return of Durant, The (1995)
# Actual Genres:  Action|Comedy|Crime|Horror
# Pridicted as:   Action|Crime|Horror
# movie_name:  Devil's Rejects, The (2005)
# Actual Genres:  Action|Comedy|Crime|Horror
# Pridicted as:   Action|Crime|Horror
# movie_name:  Helter Skelter (2004)
# Actual Genres:  Action|Comedy|Crime|Horror
# Pridicted as:   Action|Crime|Horror
# movie_name:  Serial Mom (1994)
# Actual Genres:  Action|Comedy|Crime|Horror
# Pridicted as:   Comedy|Crime|Horror
# movie_name:  From Dusk Till Dawn 2: Texas Blood Money (1999)
# Actual Genres:  Action|Comedy|Crime|Horror
# Pridicted as:   Comedy|Crime|Horror
# movie_name:  Ichi the Killer (Koroshiya 1) (2001)
# Actual Genres:  Action|Comedy|Crime|Horror
# Pridicted as:   Action|Crime|Horror|Thriller
# movie_name:  Maniac Cop (1988)
# Actual Genres:  Action|Comedy|Crime|Horror
# Pridicted as:   Action|Crime|Horror|Thriller
# movie_name:  Red State (2011)
# Actual Genres:  Action|Comedy|Crime|Horror
# Pridicted as:   Action|Crime|Horror|Thriller
# movie_name:  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# Actual Genres:  Action|Mystery|Sci-Fi|Thriller
# Pridicted as:   Mystery|Sci-Fi|Thriller
# movie_name:  Unforgettable (1996)
# Actual Genres:  Action|Mystery|Sci-Fi|Thriller
# Pridicted as:   Mystery|Sci-Fi|Thriller
# movie_name:  Omen, The (1976)
# Actual Genres:  Horror|Mystery|Sci-Fi|Thriller
# Pridicted as:   Horror|Mystery|Thriller
# movie_name:  Nico Icon (1995)
# Actual Genres:  Crime|Documentary
# Pridicted as:   Documentary
# movie_name:  Heidi Fleiss: Hollywood Madam (1995)
# Actual Genres:  Crime|Documentary
# Pridicted as:   Documentary
# movie_name:  Catwalk (1996)
# Actual Genres:  Crime|Documentary
# Pridicted as:   Documentary
# movie_name:  Anne Frank Remembered (1995)
# Actual Genres:  Crime|Documentary
# Pridicted as:   Documentary
# movie_name:  Jupiter's Wife (1994)
# Actual Genres:  Crime|Documentary
# Pridicted as:   Documentary
# movie_name:  Man of the Year (1995)
# Actual Genres:  Crime|Documentary
# Pridicted as:   Documentary
# movie_name:  Super Mario Bros. (1993)
# Actual Genres:  Adventure|Children|Fantasy|Sci-Fi
# Pridicted as:   Action|Adventure|Children|Comedy|Fantasy
# movie_name:  Joy Ride (2001)
# Actual Genres:  Adventure|Thriller
# Pridicted as:   Adventure|Drama|Thriller
# movie_name:  Alpha (2018)
# Actual Genres:  Adventure|Thriller
# Pridicted as:   Adventure|Drama|Thriller
# movie_name:  Mosquito Coast, The (1986)
# Actual Genres:  Adventure|Thriller
# Pridicted as:   Adventure|Drama|Thriller
# movie_name:  Deliverance (1972)
# Actual Genres:  Adventure|Thriller
# Pridicted as:   Adventure|Drama|Thriller
# movie_name:  Lord of the Flies (1963)
# Actual Genres:  Adventure|Thriller
# Pridicted as:   Adventure|Drama|Thriller
# movie_name:  Lord of the Flies (1990)
# Actual Genres:  Adventure|Thriller
# Pridicted as:   Adventure|Drama|Thriller
# movie_name:  Apocalypto (2006)
# Actual Genres:  Adventure|Thriller
# Pridicted as:   Adventure|Drama|Thriller
# movie_name:  Road, The (2009)
# Actual Genres:  Adventure|Thriller
# Pridicted as:   Adventure|Drama|Thriller
# movie_name:  127 Hours (2010)
# Actual Genres:  Adventure|Thriller
# Pridicted as:   Adventure|Drama|Thriller
# movie_name:  Dark Tide (2012)
# Actual Genres:  Adventure|Thriller
# Pridicted as:   Adventure|Drama|Thriller
# movie_name:  Twilight (2008)
# Actual Genres:  Drama|Fantasy|Thriller
# Pridicted as:   Drama|Fantasy|Romance
# movie_name:  Stepford Wives, The (2004)
# Actual Genres:  Drama|Fantasy|Thriller
# Pridicted as:   Comedy|Fantasy|Thriller
# movie_name:  Brass Teapot, The (2012)
# Actual Genres:  Drama|Fantasy|Thriller
# Pridicted as:   Comedy|Fantasy|Thriller
# movie_name:  Fallen (1998)
# Actual Genres:  Drama|Fantasy|Thriller
# Pridicted as:   Action|Crime|Fantasy|Thriller
# movie_name:  Three Wishes (1995)
# Actual Genres:  Drama|Fantasy|Thriller
# Pridicted as:   Drama|Fantasy
# movie_name:  Masters of the Universe (1987)
# Actual Genres:  Action|Fantasy|Sci-Fi
# Pridicted as:   Action|Adventure|Fantasy|Sci-Fi
# movie_name:  Krull (1983)
# Actual Genres:  Action|Fantasy|Sci-Fi
# Pridicted as:   Action|Adventure|Fantasy|Sci-Fi
# movie_name:  Jurassic Park (1993)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi|Thriller
# Pridicted as:   Action|Adventure|Sci-Fi|Thriller
# movie_name:  Independence Day (a.k.a. ID4) (1996)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi|Thriller
# Pridicted as:   Action|Adventure|Sci-Fi|Thriller
# movie_name:  Escape from L.A. (1996)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi|Thriller
# Pridicted as:   Action|Adventure|Sci-Fi|Thriller
# movie_name:  Incredibles, The (2004)
# Actual Genres:  Action|Adventure|Animation|Children
# Pridicted as:   Action|Adventure|Animation|Children|Comedy
# movie_name:  Asterix and Cleopatra (AstÃ©rix et ClÃ©opÃ¢tre) (1968)
# Actual Genres:  Action|Adventure|Animation|Children
# Pridicted as:   Action|Adventure|Animation|Children|Comedy
# movie_name:  Bolt (2008)
# Actual Genres:  Action|Adventure|Animation|Children
# Pridicted as:   Action|Adventure|Animation|Children|Comedy
# movie_name:  Alpha and Omega 3: The Great Wolf Games (2014)
# Actual Genres:  Action|Adventure|Animation|Children
# Pridicted as:   Action|Adventure|Animation|Children|Comedy
# movie_name:  Solo: A Star Wars Story (2018)
# Actual Genres:  Action|Adventure|Children|Sci-Fi
# Pridicted as:   Adventure|Children|Sci-Fi
# movie_name:  Honey, We Shrunk Ourselves (1997)
# Actual Genres:  Action|Adventure|Children|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Sci-Fi
# movie_name:  Flight of the Navigator (1986)
# Actual Genres:  Action|Adventure|Children|Sci-Fi
# Pridicted as:   Adventure|Children|Sci-Fi
# movie_name:  Journey to the Center of the Earth (1959)
# Actual Genres:  Action|Adventure|Children|Sci-Fi
# Pridicted as:   Adventure|Children|Sci-Fi
# movie_name:  Explorers (1985)
# Actual Genres:  Action|Adventure|Children|Sci-Fi
# Pridicted as:   Adventure|Children|Sci-Fi
# movie_name:  D.A.R.Y.L. (1985)
# Actual Genres:  Action|Adventure|Children|Sci-Fi
# Pridicted as:   Adventure|Children|Sci-Fi
# movie_name:  Last Mimzy, The (2007)
# Actual Genres:  Action|Adventure|Children|Sci-Fi
# Pridicted as:   Adventure|Children|Sci-Fi
# movie_name:  City of Ember (2008)
# Actual Genres:  Action|Adventure|Children|Sci-Fi
# Pridicted as:   Adventure|Children|Sci-Fi
# movie_name:  Doctor Who: The Waters of Mars (2009)
# Actual Genres:  Action|Adventure|Children|Sci-Fi
# Pridicted as:   Adventure|Children|Sci-Fi
# movie_name:  Doctor Who: Planet of the Dead (2009)
# Actual Genres:  Action|Adventure|Children|Sci-Fi
# Pridicted as:   Adventure|Children|Sci-Fi
# movie_name:  Brazil (1985)
# Actual Genres:  Comedy|Fantasy|Sci-Fi
# Pridicted as:   Drama|Fantasy|Sci-Fi
# movie_name:  Children of Dune (2003)
# Actual Genres:  Comedy|Fantasy|Sci-Fi
# Pridicted as:   Drama|Fantasy|Sci-Fi
# movie_name:  Kung Fury (2015)
# Actual Genres:  Comedy|Fantasy|Sci-Fi
# Pridicted as:   Action|Fantasy|Sci-Fi
# movie_name:  Nutty Professor, The (1996)
# Actual Genres:  Comedy|Fantasy|Sci-Fi
# Pridicted as:   Drama|Fantasy|Romance|Sci-Fi
# movie_name:  Ant-Man and the Wasp (2018)
# Actual Genres:  Action|Adventure|Comedy|Fantasy|Sci-Fi
# Pridicted as:   Action|Adventure|Fantasy|Sci-Fi
# movie_name:  Masters of the Universe (1987)
# Actual Genres:  Action|Adventure|Comedy|Fantasy|Sci-Fi
# Pridicted as:   Action|Adventure|Fantasy|Sci-Fi
# movie_name:  Krull (1983)
# Actual Genres:  Action|Adventure|Comedy|Fantasy|Sci-Fi
# Pridicted as:   Action|Adventure|Fantasy|Sci-Fi
# movie_name:  Godzilla vs. Mothra (Mosura tai Gojira) (1964)
# Actual Genres:  Action|Adventure|Comedy|Fantasy|Sci-Fi
# Pridicted as:   Action|Adventure|Fantasy|Sci-Fi
# movie_name:  The Pumaman (1980)
# Actual Genres:  Action|Adventure|Comedy|Fantasy|Sci-Fi
# Pridicted as:   Action|Adventure|Fantasy|Sci-Fi
# movie_name:  Thunderbirds (2004)
# Actual Genres:  Action|Adventure|Comedy|Fantasy|Sci-Fi
# Pridicted as:   Action|Adventure|Fantasy|Sci-Fi
# movie_name:  Trip to the Moon, A (Voyage dans la lune, Le) (1902)
# Actual Genres:  Action|Adventure|Comedy|Fantasy|Sci-Fi
# Pridicted as:   Action|Adventure|Fantasy|Sci-Fi
# movie_name:  Godzilla: Final Wars (Gojira: Fainaru uÃ´zu) (2004)
# Actual Genres:  Action|Adventure|Comedy|Fantasy|Sci-Fi
# Pridicted as:   Action|Adventure|Fantasy|Sci-Fi
# movie_name:  Starcrash (a.k.a. Star Crash) (1978)
# Actual Genres:  Action|Adventure|Comedy|Fantasy|Sci-Fi
# Pridicted as:   Action|Adventure|Fantasy|Sci-Fi
# movie_name:  Hellboy II: The Golden Army (2008)
# Actual Genres:  Action|Adventure|Comedy|Fantasy|Sci-Fi
# Pridicted as:   Action|Adventure|Fantasy|Sci-Fi
# movie_name:  Waterworld (1995)
# Actual Genres:  Action|Adventure|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Sci-Fi
# movie_name:  Futurama: Into the Wild Green Yonder (2009)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Animation|Sci-Fi
# movie_name:  Gintama: The Movie (2010)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Animation|Sci-Fi
# movie_name:  Spriggan (Supurigan) (1998)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Animation|Sci-Fi
# movie_name:  Evangelion: 1.0 You Are (Not) Alone (Evangerion shin gekijÃ´ban: Jo) (2007)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Animation|Sci-Fi
# movie_name:  Batman: The Dark Knight Returns, Part 1 (2012)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Animation|Sci-Fi
# movie_name:  Redline (2009)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Animation|Sci-Fi
# movie_name:  Justice League: Crisis on Two Earths (2010)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Animation|Sci-Fi
# movie_name:  Ghost in the Shell Arise - Border 1: Ghost Pain (2013)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Animation|Sci-Fi
# movie_name:  Patlabor 2: The Movie (1993)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Animation|Sci-Fi
# movie_name:  Ghost in the Shell 2.0 (2008)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Animation|Sci-Fi
# movie_name:  Mary and Max (2009)
# Actual Genres:  Animation|Drama
# Pridicted as:   Animation|Comedy|Drama
# movie_name:  My Life as McDull (Mak dau goo si) (2001)
# Actual Genres:  Animation|Drama
# Pridicted as:   Animation|Comedy|Drama
# movie_name:  Zoom (2015)
# Actual Genres:  Animation|Drama
# Pridicted as:   Animation|Comedy|Drama
# movie_name:  Black Butler: Book of the Atlantic (2017)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Action|Animation|Fantasy
# movie_name:  Dante's Inferno: An Animated Epic (2010)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Action|Animation|Fantasy
# movie_name:  Superman/Batman: Public Enemies (2009)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Action|Animation|Fantasy
# movie_name:  Justice League: Doom (2012)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Action|Animation|Fantasy
# movie_name:  Monkeybone (2001)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Animation|Comedy|Fantasy
# movie_name:  Triplets of Belleville, The (Les triplettes de Belleville) (2003)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Animation|Comedy|Fantasy
# movie_name:  Cool World (1992)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Animation|Comedy|Fantasy
# movie_name:  Mickey's Once Upon a Christmas (1999)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Animation|Comedy|Fantasy
# movie_name:  South Park: Imaginationland (2008)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Animation|Comedy|Fantasy
# movie_name:  Daddy, I'm A Zombie (2012)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Animation|Comedy|Fantasy
# movie_name:  Mezzo Forte (1998)
# Actual Genres:  Action|Animation
# Pridicted as:   Action|Animation|Comedy
# movie_name:  Big Hero 6 (2014)
# Actual Genres:  Action|Animation
# Pridicted as:   Action|Animation|Comedy
# movie_name:  Gintama: The Final Chapter - Be Forever Yorozuya (2013)
# Actual Genres:  Action|Animation
# Pridicted as:   Action|Animation|Comedy
# Hit:0.8890063641962636
# Fault:0.1109936358037364
