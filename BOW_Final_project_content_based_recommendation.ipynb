# %% [markdown]
# <a href="https://colab.research.google.com/github/MaryDongsn/GNG-5125-clustering/blob/master/BOW_Final_project_content_based_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import sqrt
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
###### Use the following code if you use google colab #####
from google.colab import drive 
drive.mount('/content/gdrive')
ratings=pd.read_csv('/content/gdrive/My Drive/gng5125 project/ratings.csv',sep=',', encoding='latin-1', usecols=['userId','movieId','rating','timestamp'])
movies = pd.read_csv('/content/gdrive/My Drive/gng5125 project/movies.csv', sep=',', encoding='latin-1', usecols=['movieId','title','genres'])
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# # Reading ratings file
# ratings = pd.read_csv('ratings.csv', sep=',', encoding='latin-1', usecols=['userId','movieId','rating','timestamp'])

# # Reading movies file
# movies = pd.read_csv('movies.csv', sep=',', encoding='latin-1', usecols=['movieId','title','genres'])

df_movies = movies 
df_ratings = ratings

# %%
# Define a TF-IDF Vectorizer Object.
from sklearn.feature_extraction.text import CountVectorizer

bows_movies_genres = CountVectorizer(token_pattern = '[a-zA-Z0-9\-]+', ngram_range=(1, 1))




#Replace NaN with an empty string
df_movies['genres'] = df_movies['genres'].replace(to_replace="(no genres listed)", value="")

#Construct the required TF-IDF matrix by fitting and transforming the data
bows_movies_genres_matrix = bows_movies_genres.fit_transform(df_movies['genres'])

# Compute the cosine similarity matrix

cosine_sim_movies = linear_kernel(bows_movies_genres_matrix, bows_movies_genres_matrix)
# print(cosine_sim_movies)

# %%
def get_recommendations_based_on_genres(movie_title, cosine_sim_movies=cosine_sim_movies):
    """
    Calculates top 2 movies to recommend based on given movie titles genres. 
    :param movie_title: title of movie to be taken for base of recommendation
    :param cosine_sim_movies: cosine similarity between movies 
    :return: Titles of movies recommended to user
    """
    # Get the index of the movie that matches the title
    idx_movie = df_movies.loc[df_movies['title'].isin([movie_title])]
    idx_movie = idx_movie.index
    
    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores_movies = list(enumerate(cosine_sim_movies[idx_movie][0]))
    
    # Sort the movies based on the similarity scores
    sim_scores_movies = sorted(sim_scores_movies, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies 
    sim_scores_movies = sim_scores_movies[0:10]

    
    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores_movies ]
   
    
    # Return the top 10 most similar movies
    return df_movies['title'].iloc[movie_indices]

# %%
get_recommendations_based_on_genres("Toy Story 2 (1999)")
# Out:
# 0                                        Toy Story (1995)
# 559                                      Space Jam (1996)
# 1706                                          Antz (1998)
# 2250                      Who Framed Roger Rabbit? (1988)
# 2355                                   Toy Story 2 (1999)
# 2809       Adventures of Rocky and Bullwinkle, The (2000)
# 3000                     Emperor's New Groove, The (2000)
# 3194                                         Shrek (2001)
# 3568                                Monsters, Inc. (2001)
# 5490    Twelve Tasks of Asterix, The (Les douze travau...
# Name: title, dtype: object

# %%
from sklearn.neighbors import KNeighborsClassifier  
def get_movie_label(movie_id):
    """
    Get the cluster label to which movie belongs by KNN algorithm.  
    :param movie_id: movie id
    :return: genres label to movie belong
    """
    classifier = KNeighborsClassifier(n_neighbors=5)
    x= bows_movies_genres_matrix
    y = df_movies.iloc[:,-1]
    classifier.fit(x, y)
    y_pred = classifier.predict(bows_movies_genres_matrix[movie_id])
    #movie_name = df_movies['title'].iloc[movie_id]

    #print ("+++++++++",type(y_pred))
    #dic = {'movie_name': movie_name, 'predected_genre': y_pred}
    # apply pandas data frame
    #df_predicted_movie = pd.DataFrame(dic)
    #return (df_predicted_movie)
    return y_pred

# %%
 get_movie_label(2355)
# Out:
# array(['Adventure|Animation|Children|Comedy|Fantasy'], dtype=object)

# %%
def get_recommendation_content_model(userId):
    """
    Calculates top movies to be recommended to user based on movie user has watched.  
    :param userId: userid of user
    :return: Titles of movies recommended to user
    """
    recommended_movie_list = []
    movie_list = []
    df_rating_filtered = df_ratings[df_ratings["userId"]== userId]
    for key, row in df_rating_filtered.iterrows():
        movie_list.append((df_movies["title"][row["movieId"]==df_movies["movieId"]]).values) 
    for index, movie in enumerate(movie_list):
        for key, movie_recommended in get_recommendations_based_on_genres(movie[0]).iteritems():
            recommended_movie_list.append(movie_recommended)

    # removing already watched movie from recommended list    
    for movie_title in recommended_movie_list:
        if movie_title in movie_list:
            recommended_movie_list.remove(movie_title)
    
    return set(recommended_movie_list)
#get_recommendation_content_model(1)
#print(type(get_recommendation_content_model(1)))

# %%
true_count = 0
false_count = 0
def evaluate_content_based_model():
    """
    Evaluate content based model.  
    """
    for key, colums in df_movies.iterrows():
        movies_recommended_by_model = get_recommendations_based_on_genres(colums["title"])
        #print(movies_recommended_by_model)
        #print(type(movies_recommended_by_model))
        
        for index, value in movies_recommended_by_model.items():
          
          predicted_genres  = get_movie_label(index)
          
          #print (type(predicted_genres))
          # full_list = (movies_recommended_by_model,predicted_genres)
          # print (full_list)
          #print(predicted_genres)
          for predicted_genre in predicted_genres:
              global true_count, false_count
              if predicted_genre == colums["genres"]:
                true_count = true_count+1
              else:
                print("movie_name: ",value)
                print("Actual Genres: ", colums["genres"])
                
                # print(colums["genres"])
                print("Pridicted as:  ", predicted_genre)

                
                false_count = false_count +1
evaluate_content_based_model()
total = true_count + false_count
print("Hit:"+ str(true_count/total))
print("Fault:" + str(false_count/total))
# Out:
# Streaming output truncated to the last 5000 lines.
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Dracula: Dead and Loving It (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Horror
# movie_name:  Money Train (1995)
# Actual Genres:  Comedy
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Toy Story (1995)
# Actual Genres:  Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Sabrina (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Dracula: Dead and Loving It (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Horror
# movie_name:  Money Train (1995)
# Actual Genres:  Comedy
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Incredibles, The (2004)
# Actual Genres:  Action|Animation|Children|Comedy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy
# movie_name:  Asterix and Cleopatra (AstÃ©rix et ClÃ©opÃ¢tre) (1968)
# Actual Genres:  Action|Animation|Children|Comedy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy
# movie_name:  Twelve Tasks of Asterix, The (Les douze travaux d'AstÃ©rix) (1976)
# Actual Genres:  Action|Animation|Children|Comedy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Chicken Little (2005)
# Actual Genres:  Action|Animation|Children|Comedy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Sci-Fi
# movie_name:  TMNT (Teenage Mutant Ninja Turtles) (2007)
# Actual Genres:  Action|Animation|Children|Comedy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Meet the Robinsons (2007)
# Actual Genres:  Action|Animation|Children|Comedy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Sci-Fi
# movie_name:  Madagascar: Escape 2 Africa (2008)
# Actual Genres:  Action|Animation|Children|Comedy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy
# movie_name:  Bolt (2008)
# Actual Genres:  Action|Animation|Children|Comedy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy
# movie_name:  Copycat (1995)
# Actual Genres:  Horror|Mystery|Thriller
# Pridicted as:   Crime|Drama|Mystery|Thriller
# movie_name:  Wes Craven's New Nightmare (Nightmare on Elm Street Part 7: Freddy's Finale, A) (1994)
# Actual Genres:  Horror|Mystery|Thriller
# Pridicted as:   Drama|Horror|Mystery|Thriller
# movie_name:  Amityville Horror, The (1979)
# Actual Genres:  Horror|Mystery|Thriller
# Pridicted as:   Drama|Horror|Mystery|Thriller
# movie_name:  Scream (1996)
# Actual Genres:  Horror|Mystery|Thriller
# Pridicted as:   Comedy|Horror|Mystery|Thriller
# movie_name:  Scream 2 (1997)
# Actual Genres:  Horror|Mystery|Thriller
# Pridicted as:   Comedy|Horror|Mystery|Thriller
# movie_name:  Cube (1997)
# Actual Genres:  Horror|Mystery|Thriller
# Pridicted as:   Horror|Mystery|Sci-Fi|Thriller
# movie_name:  Toy Story (1995)
# Actual Genres:  Adventure|Animation|Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Aladdin (1992)
# Actual Genres:  Adventure|Animation|Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  Space Jam (1996)
# Actual Genres:  Adventure|Animation|Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Oliver & Company (1988)
# Actual Genres:  Adventure|Animation|Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  Grand Day Out with Wallace and Gromit, A (1989)
# Actual Genres:  Adventure|Animation|Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy
# movie_name:  Hercules (1997)
# Actual Genres:  Adventure|Animation|Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  Mulan (1998)
# Actual Genres:  Adventure|Animation|Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Drama|Musical|Romance
# movie_name:  American Tail, An (1986)
# Actual Genres:  Adventure|Animation|Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy
# movie_name:  Money Train (1995)
# Actual Genres:  Comedy|Crime|Drama
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Bad Boys (1995)
# Actual Genres:  Comedy|Crime|Drama
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Pulp Fiction (1994)
# Actual Genres:  Comedy|Crime|Drama
# Pridicted as:   Comedy|Crime|Drama|Thriller
# movie_name:  Fargo (1996)
# Actual Genres:  Comedy|Crime|Drama
# Pridicted as:   Comedy|Crime|Drama|Thriller
# movie_name:  Beat the Devil (1953)
# Actual Genres:  Comedy|Crime|Drama
# Pridicted as:   Adventure|Comedy|Crime|Drama|Romance
# movie_name:  Freeway (1996)
# Actual Genres:  Comedy|Crime|Drama
# Pridicted as:   Comedy|Crime|Drama|Thriller
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Casino (1995)
# Actual Genres:  Drama
# Pridicted as:   Crime|Drama
# movie_name:  Sense and Sensibility (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Romance
# movie_name:  Money Train (1995)
# Actual Genres:  Drama
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Copycat (1995)
# Actual Genres:  Drama
# Pridicted as:   Crime|Drama|Mystery|Thriller
# movie_name:  Powder (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Sci-Fi
# movie_name:  Leaving Las Vegas (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Romance
# movie_name:  Toy Story (1995)
# Actual Genres:
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Jumanji (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Father of the Bride Part II (1995)
# Actual Genres:
# Pridicted as:   Comedy
# movie_name:  Heat (1995)
# Actual Genres:
# Pridicted as:   Action|Crime|Thriller
# movie_name:  Sabrina (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Tom and Huck (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children
# movie_name:  Sudden Death (1995)
# Actual Genres:
# Pridicted as:   Action
# movie_name:  GoldenEye (1995)
# Actual Genres:
# Pridicted as:   Action|Adventure|Thriller
# movie_name:  Toy Story (1995)
# Actual Genres:
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Jumanji (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Father of the Bride Part II (1995)
# Actual Genres:
# Pridicted as:   Comedy
# movie_name:  Heat (1995)
# Actual Genres:
# Pridicted as:   Action|Crime|Thriller
# movie_name:  Sabrina (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Tom and Huck (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children
# movie_name:  Sudden Death (1995)
# Actual Genres:
# Pridicted as:   Action
# movie_name:  GoldenEye (1995)
# Actual Genres:
# Pridicted as:   Action|Adventure|Thriller
# movie_name:  Toy Story (1995)
# Actual Genres:  Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Sabrina (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Dracula: Dead and Loving It (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Horror
# movie_name:  Money Train (1995)
# Actual Genres:  Comedy
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Casino (1995)
# Actual Genres:  Drama
# Pridicted as:   Crime|Drama
# movie_name:  Sense and Sensibility (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Romance
# movie_name:  Money Train (1995)
# Actual Genres:  Drama
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Copycat (1995)
# Actual Genres:  Drama
# Pridicted as:   Crime|Drama|Mystery|Thriller
# movie_name:  Powder (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Sci-Fi
# movie_name:  Leaving Las Vegas (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Romance
# movie_name:  Toy Story (1995)
# Actual Genres:
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Jumanji (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Father of the Bride Part II (1995)
# Actual Genres:
# Pridicted as:   Comedy
# movie_name:  Heat (1995)
# Actual Genres:
# Pridicted as:   Action|Crime|Thriller
# movie_name:  Sabrina (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Tom and Huck (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children
# movie_name:  Sudden Death (1995)
# Actual Genres:
# Pridicted as:   Action
# movie_name:  GoldenEye (1995)
# Actual Genres:
# Pridicted as:   Action|Adventure|Thriller
# movie_name:  Toy Story (1995)
# Actual Genres:  Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Sabrina (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Dracula: Dead and Loving It (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Horror
# movie_name:  Money Train (1995)
# Actual Genres:  Comedy
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Outlaw Josey Wales, The (1976)
# Actual Genres:  Drama|Thriller|Western
# Pridicted as:   Action|Adventure|Drama|Thriller
# movie_name:  For a Few Dollars More (Per qualche dollaro in piÃ¹) (1965)
# Actual Genres:  Drama|Thriller|Western
# Pridicted as:   Action|Drama|Thriller|Western
# movie_name:  3:10 to Yuma (1957)
# Actual Genres:  Drama|Thriller|Western
# Pridicted as:   Action|Adventure|Drama|Thriller
# movie_name:  Bad Day at Black Rock (1955)
# Actual Genres:  Drama|Thriller|Western
# Pridicted as:   Drama|Thriller
# movie_name:  Northwest Passage (1940)
# Actual Genres:  Drama|Thriller|Western
# Pridicted as:   Action|Adventure|Drama|Thriller|Western
# movie_name:  Jonah Hex (2010)
# Actual Genres:  Drama|Thriller|Western
# Pridicted as:   Action|Drama|Thriller|Western
# movie_name:  Rubber (2010)
# Actual Genres:  Drama|Thriller|Western
# Pridicted as:   Action|Adventure|Comedy|Crime|Drama|Film-Noir|Horror|Mystery|Thriller|Western
# movie_name:  A Man Called Blade (1977)
# Actual Genres:  Drama|Thriller|Western
# Pridicted as:   Action|Drama|Thriller|Western
# movie_name:  The Beguiled (2017)
# Actual Genres:  Drama|Thriller|Western
# Pridicted as:   Drama|Thriller
# movie_name:  Money Train (1995)
# Actual Genres:  Drama|Thriller|Western
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Money Train (1995)
# Actual Genres:  Action|Crime|Thriller
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Crossing Guard, The (1995)
# Actual Genres:  Action|Crime|Thriller
# Pridicted as:   Action|Crime|Drama|Thriller
# movie_name:  Bad Boys (1995)
# Actual Genres:  Action|Crime|Thriller
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Hackers (1995)
# Actual Genres:  Action|Crime|Thriller
# Pridicted as:   Action|Adventure|Crime|Thriller
# movie_name:  Strange Days (1995)
# Actual Genres:  Action|Crime|Thriller
# Pridicted as:   Action|Crime|Drama|Mystery|Sci-Fi|Thriller
# movie_name:  Day After Tomorrow, The (2004)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi
# Pridicted as:   Action|Adventure|Drama|Sci-Fi|Thriller
# movie_name:  Sound of Thunder, A (2005)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi
# Pridicted as:   Action|Adventure|Drama|Sci-Fi|Thriller
# movie_name:  Children of Men (2006)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi
# Pridicted as:   Action|Adventure|Drama|Sci-Fi|Thriller
# movie_name:  Jumper (2008)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi
# Pridicted as:   Action|Adventure|Drama|Sci-Fi|Thriller
# movie_name:  Aelita: The Queen of Mars (Aelita) (1924)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi
# Pridicted as:   Action|Adventure|Drama|Sci-Fi|Thriller
# movie_name:  The Hunger Games (2012)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi
# Pridicted as:   Action|Adventure|Drama|Sci-Fi|Thriller
# movie_name:  Slaughterhouse-Five (1972)
# Actual Genres:  Comedy|Sci-Fi|War
# Pridicted as:   Comedy|Drama|War
# movie_name:  Embassy (2013)
# Actual Genres:  Comedy|Sci-Fi|War
# Pridicted as:   Comedy|Sci-Fi
# movie_name:  Canadian Bacon (1995)
# Actual Genres:  Comedy|Sci-Fi|War
# Pridicted as:   Comedy|War
# movie_name:  Junior (1994)
# Actual Genres:  Comedy|Sci-Fi|War
# Pridicted as:   Comedy|Sci-Fi
# movie_name:  Tank Girl (1995)
# Actual Genres:  Comedy|Sci-Fi|War
# Pridicted as:   Action|Comedy|Sci-Fi
# movie_name:  Forrest Gump (1994)
# Actual Genres:  Comedy|Sci-Fi|War
# Pridicted as:   Comedy|Drama|Romance|War
# movie_name:  Coneheads (1993)
# Actual Genres:  Comedy|Sci-Fi|War
# Pridicted as:   Comedy|Sci-Fi
# movie_name:  Hot Shots! Part Deux (1993)
# Actual Genres:  Comedy|Sci-Fi|War
# Pridicted as:   Action|Comedy
# movie_name:  In the Army Now (1994)
# Actual Genres:  Comedy|Sci-Fi|War
# Pridicted as:   Comedy|War
# movie_name:  Super Mario Bros. (1993)
# Actual Genres:  Comedy|Sci-Fi|War
# Pridicted as:   Action|Adventure|Children|Comedy|Fantasy
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Comedy|Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Comedy|Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Money Train (1995)
# Actual Genres:  Comedy|Drama
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  To Die For (1995)
# Actual Genres:  Comedy|Drama
# Pridicted as:   Comedy|Drama|Thriller
# movie_name:  Mighty Aphrodite (1995)
# Actual Genres:  Comedy|Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Postman, The (Postino, Il) (1994)
# Actual Genres:  Comedy|Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Beautiful Girls (1996)
# Actual Genres:  Comedy|Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Toy Story (1995)
# Actual Genres:
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Jumanji (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Father of the Bride Part II (1995)
# Actual Genres:
# Pridicted as:   Comedy
# movie_name:  Heat (1995)
# Actual Genres:
# Pridicted as:   Action|Crime|Thriller
# movie_name:  Sabrina (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Tom and Huck (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children
# movie_name:  Sudden Death (1995)
# Actual Genres:
# Pridicted as:   Action
# movie_name:  GoldenEye (1995)
# Actual Genres:
# Pridicted as:   Action|Adventure|Thriller
# movie_name:  Copycat (1995)
# Actual Genres:  Drama|Mystery|Thriller
# Pridicted as:   Crime|Drama|Mystery|Thriller
# movie_name:  Strange Days (1995)
# Actual Genres:  Drama|Mystery|Thriller
# Pridicted as:   Action|Crime|Drama|Mystery|Sci-Fi|Thriller
# movie_name:  Wes Craven's New Nightmare (Nightmare on Elm Street Part 7: Freddy's Finale, A) (1994)
# Actual Genres:  Drama|Mystery|Thriller
# Pridicted as:   Drama|Horror|Mystery|Thriller
# movie_name:  Boxing Helena (1993)
# Actual Genres:  Drama|Mystery|Thriller
# Pridicted as:   Drama|Mystery|Romance|Thriller
# movie_name:  Primal Fear (1996)
# Actual Genres:  Drama|Mystery|Thriller
# Pridicted as:   Crime|Drama|Mystery|Thriller
# movie_name:  Alphaville (Alphaville, une Ã©trange aventure de Lemmy Caution) (1965)
# Actual Genres:  Drama|Mystery|Thriller
# Pridicted as:   Drama|Mystery|Romance|Thriller
# movie_name:  Vertigo (1958)
# Actual Genres:  Drama|Mystery|Thriller
# Pridicted as:   Drama|Mystery|Romance|Thriller
# movie_name:  Rebecca (1940)
# Actual Genres:  Drama|Mystery|Thriller
# Pridicted as:   Drama|Mystery|Romance|Thriller
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Casino (1995)
# Actual Genres:  Drama
# Pridicted as:   Crime|Drama
# movie_name:  Sense and Sensibility (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Romance
# movie_name:  Money Train (1995)
# Actual Genres:  Drama
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Copycat (1995)
# Actual Genres:  Drama
# Pridicted as:   Crime|Drama|Mystery|Thriller
# movie_name:  Powder (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Sci-Fi
# movie_name:  Leaving Las Vegas (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Romance
# movie_name:  Toy Story (1995)
# Actual Genres:  Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Sabrina (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Dracula: Dead and Loving It (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Horror
# movie_name:  Money Train (1995)
# Actual Genres:  Comedy
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Charade (1963)
# Actual Genres:  Comedy|Mystery|Romance|Thriller
# Pridicted as:   Comedy|Crime|Mystery|Romance
# movie_name:  Plain Clothes (1988)
# Actual Genres:  Comedy|Mystery|Romance|Thriller
# Pridicted as:   Comedy|Mystery|Thriller
# movie_name:  True Lies (1994)
# Actual Genres:  Comedy|Mystery|Romance|Thriller
# Pridicted as:   Action|Adventure|Comedy|Romance
# movie_name:  Boxing Helena (1993)
# Actual Genres:  Comedy|Mystery|Romance|Thriller
# Pridicted as:   Drama|Mystery|Romance|Thriller
# movie_name:  What Happened Was... (1994)
# Actual Genres:  Comedy|Mystery|Romance|Thriller
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Radioland Murders (1994)
# Actual Genres:  Comedy|Mystery|Romance|Thriller
# Pridicted as:   Comedy|Romance
# movie_name:  So I Married an Axe Murderer (1993)
# Actual Genres:  Comedy|Mystery|Romance|Thriller
# Pridicted as:   Comedy|Romance|Thriller
# movie_name:  Ghost (1990)
# Actual Genres:  Comedy|Mystery|Romance|Thriller
# Pridicted as:   Comedy|Drama|Fantasy|Romance
# movie_name:  Alphaville (Alphaville, une Ã©trange aventure de Lemmy Caution) (1965)
# Actual Genres:  Comedy|Mystery|Romance|Thriller
# Pridicted as:   Drama|Mystery|Romance|Thriller
# movie_name:  Vertigo (1958)
# Actual Genres:  Comedy|Mystery|Romance|Thriller
# Pridicted as:   Drama|Mystery|Romance|Thriller
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Drama|Romance
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Drama|Romance
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Pocahontas (1995)
# Actual Genres:  Drama|Romance
# Pridicted as:   Animation|Children|Drama|Musical|Romance
# movie_name:  Mighty Aphrodite (1995)
# Actual Genres:  Drama|Romance
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Postman, The (Postino, Il) (1994)
# Actual Genres:  Drama|Romance
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Toy Story (1995)
# Actual Genres:  Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Sabrina (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Dracula: Dead and Loving It (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Horror
# movie_name:  Money Train (1995)
# Actual Genres:  Comedy
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Toy Story (1995)
# Actual Genres:  Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Sabrina (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Dracula: Dead and Loving It (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Horror
# movie_name:  Money Train (1995)
# Actual Genres:  Comedy
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Toy Story (1995)
# Actual Genres:
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Jumanji (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Father of the Bride Part II (1995)
# Actual Genres:
# Pridicted as:   Comedy
# movie_name:  Heat (1995)
# Actual Genres:
# Pridicted as:   Action|Crime|Thriller
# movie_name:  Sabrina (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Tom and Huck (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children
# movie_name:  Sudden Death (1995)
# Actual Genres:
# Pridicted as:   Action
# movie_name:  GoldenEye (1995)
# Actual Genres:
# Pridicted as:   Action|Adventure|Thriller
# movie_name:  Toy Story (1995)
# Actual Genres:  Adventure|Animation|Children|Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Aladdin (1992)
# Actual Genres:  Adventure|Animation|Children|Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  Space Jam (1996)
# Actual Genres:  Adventure|Animation|Children|Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Oliver & Company (1988)
# Actual Genres:  Adventure|Animation|Children|Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  Hercules (1997)
# Actual Genres:  Adventure|Animation|Children|Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  Mulan (1998)
# Actual Genres:  Adventure|Animation|Children|Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Drama|Musical|Romance
# movie_name:  Antz (1998)
# Actual Genres:  Adventure|Animation|Children|Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Toy Story (1995)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Space Jam (1996)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Aladdin and the King of Thieves (1996)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy|Musical|Romance
# movie_name:  Antz (1998)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Who Framed Roger Rabbit? (1988)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Toy Story 2 (1999)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Adventures of Rocky and Bullwinkle, The (2000)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Emperor's New Groove, The (2000)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Shrek (2001)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy|Romance
# movie_name:  Toy Story (1995)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Balto (1995)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children
# movie_name:  Pocahontas (1995)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Drama|Musical|Romance
# movie_name:  Goofy Movie, A (1995)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Comedy|Romance
# movie_name:  Swan Princess, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children
# movie_name:  Lion King, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Drama
# movie_name:  Nightmare Before Christmas, The (1993)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Fantasy|Musical
# movie_name:  Pagemaster, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Action|Adventure|Animation|Children
# movie_name:  Aladdin (1992)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  Snow White and the Seven Dwarfs (1937)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Fantasy|Musical
# movie_name:  Toy Story (1995)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Lion King, The (1994)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Adventure|Animation|Children|Drama
# movie_name:  Pagemaster, The (1994)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Action|Adventure|Animation|Children
# movie_name:  Aladdin (1992)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  All Dogs Go to Heaven 2 (1996)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Adventure|Animation|Children|Fantasy|Musical
# movie_name:  James and the Giant Peach (1996)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Adventure|Animation|Children|Fantasy|Musical
# movie_name:  Space Jam (1996)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Oliver & Company (1988)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  Land Before Time III: The Time of the Great Giving (1995)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Adventure|Animation|Children|Musical
# movie_name:  Toy Story (1995)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Balto (1995)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children
# movie_name:  Pocahontas (1995)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Drama|Musical|Romance
# movie_name:  Goofy Movie, A (1995)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Comedy|Romance
# movie_name:  Swan Princess, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children
# movie_name:  Lion King, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Drama
# movie_name:  Nightmare Before Christmas, The (1993)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Fantasy|Musical
# movie_name:  Pagemaster, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Action|Adventure|Animation|Children
# movie_name:  Aladdin (1992)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  Snow White and the Seven Dwarfs (1937)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Fantasy|Musical
# movie_name:  Toy Story (1995)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Balto (1995)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children
# movie_name:  Pocahontas (1995)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Drama|Musical|Romance
# movie_name:  Goofy Movie, A (1995)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Comedy|Romance
# movie_name:  Swan Princess, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children
# movie_name:  Lion King, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Drama
# movie_name:  Nightmare Before Christmas, The (1993)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Fantasy|Musical
# movie_name:  Pagemaster, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Action|Adventure|Animation|Children
# movie_name:  Aladdin (1992)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  Snow White and the Seven Dwarfs (1937)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Fantasy|Musical
# movie_name:  Toy Story (1995)
# Actual Genres:
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Jumanji (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Father of the Bride Part II (1995)
# Actual Genres:
# Pridicted as:   Comedy
# movie_name:  Heat (1995)
# Actual Genres:
# Pridicted as:   Action|Crime|Thriller
# movie_name:  Sabrina (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Tom and Huck (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children
# movie_name:  Sudden Death (1995)
# Actual Genres:
# Pridicted as:   Action
# movie_name:  GoldenEye (1995)
# Actual Genres:
# Pridicted as:   Action|Adventure|Thriller
# movie_name:  Team America: World Police (2004)
# Actual Genres:  Action|Adventure|Animation|Comedy
# Pridicted as:   Action|Adventure|Animation
# movie_name:  Incredibles, The (2004)
# Actual Genres:  Action|Adventure|Animation|Comedy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy
# movie_name:  Asterix and Cleopatra (AstÃ©rix et ClÃ©opÃ¢tre) (1968)
# Actual Genres:  Action|Adventure|Animation|Comedy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy
# movie_name:  Twelve Tasks of Asterix, The (Les douze travaux d'AstÃ©rix) (1976)
# Actual Genres:  Action|Adventure|Animation|Comedy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Chicken Little (2005)
# Actual Genres:  Action|Adventure|Animation|Comedy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Sci-Fi
# movie_name:  TMNT (Teenage Mutant Ninja Turtles) (2007)
# Actual Genres:  Action|Adventure|Animation|Comedy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Meet the Robinsons (2007)
# Actual Genres:  Action|Adventure|Animation|Comedy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Sci-Fi
# movie_name:  Aqua Teen Hunger Force Colon Movie Film for Theaters (2007)
# Actual Genres:  Action|Adventure|Animation|Comedy
# Pridicted as:   Action|Adventure|Animation|Fantasy|Sci-Fi
# movie_name:  Futurama: Bender's Game (2008)
# Actual Genres:  Action|Adventure|Animation|Comedy
# Pridicted as:   Action|Adventure|Animation|Fantasy|Sci-Fi
# movie_name:  Toy Story (1995)
# Actual Genres:  Adventure|Animation|Children|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Pagemaster, The (1994)
# Actual Genres:  Adventure|Animation|Children|Fantasy
# Pridicted as:   Action|Adventure|Animation|Children
# movie_name:  All Dogs Go to Heaven 2 (1996)
# Actual Genres:  Adventure|Animation|Children|Fantasy
# Pridicted as:   Adventure|Animation|Children|Fantasy|Musical
# movie_name:  James and the Giant Peach (1996)
# Actual Genres:  Adventure|Animation|Children|Fantasy
# Pridicted as:   Adventure|Animation|Children|Fantasy|Musical
# movie_name:  Space Jam (1996)
# Actual Genres:  Adventure|Animation|Children|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Alice in Wonderland (1951)
# Actual Genres:  Adventure|Animation|Children|Fantasy
# Pridicted as:   Adventure|Animation|Children|Fantasy|Musical
# movie_name:  Quest for Camelot (1998)
# Actual Genres:  Adventure|Animation|Children|Fantasy
# Pridicted as:   Adventure|Animation|Children|Fantasy|Musical
# movie_name:  Return of Jafar, The (1994)
# Actual Genres:  Adventure|Animation|Children|Fantasy
# Pridicted as:   Adventure|Animation|Children|Fantasy|Musical
# movie_name:  Toy Story (1995)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Lion King, The (1994)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Adventure|Animation|Children|Drama
# movie_name:  Pagemaster, The (1994)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Action|Adventure|Animation|Children
# movie_name:  Aladdin (1992)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  All Dogs Go to Heaven 2 (1996)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Adventure|Animation|Children|Fantasy|Musical
# movie_name:  James and the Giant Peach (1996)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Adventure|Animation|Children|Fantasy|Musical
# movie_name:  Space Jam (1996)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Oliver & Company (1988)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  Land Before Time III: The Time of the Great Giving (1995)
# Actual Genres:  Adventure|Animation|Children
# Pridicted as:   Adventure|Animation|Children|Musical
# movie_name:  Heavy Metal (1981)
# Actual Genres:  Animation|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Sci-Fi
# movie_name:  Space Jam (1996)
# Actual Genres:  Animation|Sci-Fi
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Grand Day Out with Wallace and Gromit, A (1989)
# Actual Genres:  Animation|Sci-Fi
# Pridicted as:   Adventure|Animation|Children|Comedy
# movie_name:  Akira (1988)
# Actual Genres:  Animation|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Sci-Fi
# movie_name:  Iron Giant, The (1999)
# Actual Genres:  Animation|Sci-Fi
# Pridicted as:   Adventure|Animation|Children|Sci-Fi
# movie_name:  PokÃ©mon: The First Movie (1998)
# Actual Genres:  Animation|Sci-Fi
# Pridicted as:   Adventure|Children|Fantasy|Sci-Fi
# movie_name:  Light Years (Gandahar) (1988)
# Actual Genres:  Animation|Sci-Fi
# Pridicted as:   Adventure|Animation|Fantasy|Sci-Fi
# movie_name:  Heavy Metal (1981)
# Actual Genres:  Action|Animation|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Sci-Fi
# movie_name:  Akira (1988)
# Actual Genres:  Action|Animation|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Sci-Fi
# movie_name:  Titan A.E. (2000)
# Actual Genres:  Action|Animation|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Sci-Fi
# movie_name:  Heavy Metal 2000 (2000)
# Actual Genres:  Action|Animation|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Fantasy|Sci-Fi
# movie_name:  Cowboy Bebop: The Movie (Cowboy Bebop: Tengoku no Tobira) (2001)
# Actual Genres:  Action|Animation|Sci-Fi
# Pridicted as:   Action|Sci-Fi|Thriller
# movie_name:  Laputa: Castle in the Sky (TenkÃ» no shiro Rapyuta) (1986)
# Actual Genres:  Action|Animation|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Children|Fantasy|Sci-Fi
# movie_name:  G.I. Joe: The Movie (1987)
# Actual Genres:  Action|Animation|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Children|Fantasy|Sci-Fi
# movie_name:  Patlabor: The Movie (KidÃ´ keisatsu patorebÃ¢: The Movie) (1989)
# Actual Genres:  Action|Animation|Sci-Fi
# Pridicted as:   Action|Crime|Drama|Mystery|Thriller
# movie_name:  Batman/Superman Movie, The (1998)
# Actual Genres:  Action|Animation|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Children|Fantasy|Sci-Fi
# movie_name:  Heavy Metal (1981)
# Actual Genres:  Animation|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Sci-Fi
# movie_name:  Space Jam (1996)
# Actual Genres:  Animation|Sci-Fi
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Grand Day Out with Wallace and Gromit, A (1989)
# Actual Genres:  Animation|Sci-Fi
# Pridicted as:   Adventure|Animation|Children|Comedy
# movie_name:  Akira (1988)
# Actual Genres:  Animation|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Sci-Fi
# movie_name:  Iron Giant, The (1999)
# Actual Genres:  Animation|Sci-Fi
# Pridicted as:   Adventure|Animation|Children|Sci-Fi
# movie_name:  PokÃ©mon: The First Movie (1998)
# Actual Genres:  Animation|Sci-Fi
# Pridicted as:   Adventure|Children|Fantasy|Sci-Fi
# movie_name:  Light Years (Gandahar) (1988)
# Actual Genres:  Animation|Sci-Fi
# Pridicted as:   Adventure|Animation|Fantasy|Sci-Fi
# movie_name:  Toy Story (1995)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Balto (1995)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children
# movie_name:  Pocahontas (1995)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Drama|Musical|Romance
# movie_name:  Goofy Movie, A (1995)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Comedy|Romance
# movie_name:  Swan Princess, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children
# movie_name:  Lion King, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Drama
# movie_name:  Nightmare Before Christmas, The (1993)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Fantasy|Musical
# movie_name:  Pagemaster, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Action|Adventure|Animation|Children
# movie_name:  Aladdin (1992)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  Snow White and the Seven Dwarfs (1937)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Fantasy|Musical
# movie_name:  Day After Tomorrow, The (2004)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi
# Pridicted as:   Action|Adventure|Drama|Sci-Fi|Thriller
# movie_name:  Sound of Thunder, A (2005)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi
# Pridicted as:   Action|Adventure|Drama|Sci-Fi|Thriller
# movie_name:  Children of Men (2006)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi
# Pridicted as:   Action|Adventure|Drama|Sci-Fi|Thriller
# movie_name:  Jumper (2008)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi
# Pridicted as:   Action|Adventure|Drama|Sci-Fi|Thriller
# movie_name:  Aelita: The Queen of Mars (Aelita) (1924)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi
# Pridicted as:   Action|Adventure|Drama|Sci-Fi|Thriller
# movie_name:  The Hunger Games (2012)
# Actual Genres:  Action|Adventure|Drama|Sci-Fi
# Pridicted as:   Action|Adventure|Drama|Sci-Fi|Thriller
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Casino (1995)
# Actual Genres:  Drama
# Pridicted as:   Crime|Drama
# movie_name:  Sense and Sensibility (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Romance
# movie_name:  Money Train (1995)
# Actual Genres:  Drama
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Copycat (1995)
# Actual Genres:  Drama
# Pridicted as:   Crime|Drama|Mystery|Thriller
# movie_name:  Powder (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Sci-Fi
# movie_name:  Leaving Las Vegas (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Romance
# movie_name:  Toy Story (1995)
# Actual Genres:  Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Sabrina (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Dracula: Dead and Loving It (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Horror
# movie_name:  Money Train (1995)
# Actual Genres:  Comedy
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Forrest Gump (1994)
# Actual Genres:  Comedy|Drama|War
# Pridicted as:   Comedy|Drama|Romance|War
# movie_name:  Life Is Beautiful (La Vita Ã¨ bella) (1997)
# Actual Genres:  Comedy|Drama|War
# Pridicted as:   Comedy|Drama|Romance|War
# movie_name:  Three Kings (1999)
# Actual Genres:  Comedy|Drama|War
# Pridicted as:   Action|Adventure|Comedy|Drama|War
# movie_name:  Train of Life (Train de vie) (1998)
# Actual Genres:  Comedy|Drama|War
# Pridicted as:   Comedy|Drama|Romance|War
# movie_name:  Toy Story (1995)
# Actual Genres:  Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Sabrina (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Dracula: Dead and Loving It (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Horror
# movie_name:  Money Train (1995)
# Actual Genres:  Comedy
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Toy Story (1995)
# Actual Genres:  Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Sabrina (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Dracula: Dead and Loving It (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Horror
# movie_name:  Money Train (1995)
# Actual Genres:  Comedy
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Jurassic Park (1993)
# Actual Genres:  Action|Adventure|Sci-Fi
# Pridicted as:   Action|Adventure|Sci-Fi|Thriller
# movie_name:  Super Mario Bros. (1993)
# Actual Genres:  Action|Adventure|Sci-Fi
# Pridicted as:   Action|Adventure|Children|Comedy|Fantasy
# movie_name:  Heavy Metal (1981)
# Actual Genres:  Action|Adventure|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Sci-Fi
# movie_name:  Independence Day (a.k.a. ID4) (1996)
# Actual Genres:  Action|Adventure|Sci-Fi
# Pridicted as:   Action|Adventure|Sci-Fi|Thriller
# movie_name:  Escape from L.A. (1996)
# Actual Genres:  Action|Adventure|Sci-Fi
# Pridicted as:   Action|Adventure|Sci-Fi|Thriller
# movie_name:  Heavy Metal (1981)
# Actual Genres:  Action|Horror|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Sci-Fi
# movie_name:  Lawnmower Man, The (1992)
# Actual Genres:  Action|Horror|Sci-Fi
# Pridicted as:   Action|Horror|Sci-Fi|Thriller
# movie_name:  Aliens (1986)
# Actual Genres:  Action|Horror|Sci-Fi
# Pridicted as:   Action|Adventure|Horror|Sci-Fi
# movie_name:  AlienÂ³ (a.k.a. Alien 3) (1992)
# Actual Genres:  Action|Horror|Sci-Fi
# Pridicted as:   Action|Horror|Sci-Fi|Thriller
# movie_name:  Thing, The (1982)
# Actual Genres:  Action|Horror|Sci-Fi
# Pridicted as:   Action|Horror|Sci-Fi|Thriller
# movie_name:  Godzilla 1985: The Legend Is Reborn (Gojira) (Godzilla) (Return of Godzilla, The) (1984)
# Actual Genres:  Action|Horror|Sci-Fi
# Pridicted as:   Action|Horror|Sci-Fi|Thriller
# movie_name:  Toy Story (1995)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Space Jam (1996)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Aladdin and the King of Thieves (1996)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy|Musical|Romance
# movie_name:  Antz (1998)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Who Framed Roger Rabbit? (1988)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Toy Story 2 (1999)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Adventures of Rocky and Bullwinkle, The (2000)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Emperor's New Groove, The (2000)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Shrek (2001)
# Actual Genres:  Animation|Children|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy|Romance
# movie_name:  Toy Story (1995)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Balto (1995)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children
# movie_name:  Pocahontas (1995)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Drama|Musical|Romance
# movie_name:  Goofy Movie, A (1995)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Comedy|Romance
# movie_name:  Swan Princess, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children
# movie_name:  Lion King, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Drama
# movie_name:  Nightmare Before Christmas, The (1993)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Fantasy|Musical
# movie_name:  Pagemaster, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Action|Adventure|Animation|Children
# movie_name:  Aladdin (1992)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  Snow White and the Seven Dwarfs (1937)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Fantasy|Musical
# movie_name:  Toy Story (1995)
# Actual Genres:
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Jumanji (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Father of the Bride Part II (1995)
# Actual Genres:
# Pridicted as:   Comedy
# movie_name:  Heat (1995)
# Actual Genres:
# Pridicted as:   Action|Crime|Thriller
# movie_name:  Sabrina (1995)
# Actual Genres:
# Pridicted as:   Comedy|Romance
# movie_name:  Tom and Huck (1995)
# Actual Genres:
# Pridicted as:   Adventure|Children
# movie_name:  Sudden Death (1995)
# Actual Genres:
# Pridicted as:   Action
# movie_name:  GoldenEye (1995)
# Actual Genres:
# Pridicted as:   Action|Adventure|Thriller
# movie_name:  Money Train (1995)
# Actual Genres:  Comedy|Crime
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Get Shorty (1995)
# Actual Genres:  Comedy|Crime
# Pridicted as:   Comedy|Crime|Thriller
# movie_name:  Bottle Rocket (1996)
# Actual Genres:  Comedy|Crime
# Pridicted as:   Adventure|Comedy|Crime|Romance
# movie_name:  Rumble in the Bronx (Hont faan kui) (1995)
# Actual Genres:  Comedy|Crime
# Pridicted as:   Action|Adventure|Comedy|Crime
# movie_name:  Bad Boys (1995)
# Actual Genres:  Comedy|Crime
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Batman Forever (1995)
# Actual Genres:  Comedy|Crime
# ...
# movie_name:  Fargo (1996)
# Actual Genres:  Comedy|Crime|Drama
# Pridicted as:   Comedy|Crime|Drama|Thriller
# movie_name:  Beat the Devil (1953)
# Actual Genres:  Comedy|Crime|Drama
# Pridicted as:   Adventure|Comedy|Crime|Drama|Romance
# movie_name:  Freeway (1996)
# Actual Genres:  Comedy|Crime|Drama
# Pridicted as:   Comedy|Crime|Drama|Thriller
# movie_name:  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# Actual Genres:  Sci-Fi|Thriller
# Pridicted as:   Mystery|Sci-Fi|Thriller
# movie_name:  Lawnmower Man 2: Beyond Cyberspace (1996)
# Actual Genres:  Sci-Fi|Thriller
# Pridicted as:   Action|Sci-Fi|Thriller
# movie_name:  Screamers (1995)
# Actual Genres:  Sci-Fi|Thriller
# Pridicted as:   Action|Sci-Fi|Thriller
# movie_name:  Unforgettable (1996)
# Actual Genres:  Sci-Fi|Thriller
# Pridicted as:   Mystery|Sci-Fi|Thriller
# movie_name:  Johnny Mnemonic (1995)
# Actual Genres:  Sci-Fi|Thriller
# Pridicted as:   Action|Sci-Fi|Thriller
# movie_name:  Strange Days (1995)
# Actual Genres:  Sci-Fi|Thriller
# Pridicted as:   Action|Crime|Drama|Mystery|Sci-Fi|Thriller
# movie_name:  Outbreak (1995)
# Actual Genres:  Sci-Fi|Thriller
# Pridicted as:   Action|Drama|Sci-Fi|Thriller
# movie_name:  Virtuosity (1995)
# Actual Genres:  Sci-Fi|Thriller
# Pridicted as:   Action|Sci-Fi|Thriller
# movie_name:  Timecop (1994)
# Actual Genres:  Sci-Fi|Thriller
# Pridicted as:   Action|Sci-Fi|Thriller
# movie_name:  Body Snatchers (1993)
# Actual Genres:  Sci-Fi|Thriller
# Pridicted as:   Horror|Sci-Fi|Thriller
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Drama|Romance
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Drama|Romance
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Pocahontas (1995)
# Actual Genres:  Drama|Romance
# Pridicted as:   Animation|Children|Drama|Musical|Romance
# movie_name:  Mighty Aphrodite (1995)
# Actual Genres:  Drama|Romance
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Postman, The (Postino, Il) (1994)
# Actual Genres:  Drama|Romance
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Toy Story (1995)
# Actual Genres:  Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Sabrina (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Dracula: Dead and Loving It (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Horror
# movie_name:  Money Train (1995)
# Actual Genres:  Comedy
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Casino (1995)
# Actual Genres:  Drama
# Pridicted as:   Crime|Drama
# movie_name:  Sense and Sensibility (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Romance
# movie_name:  Money Train (1995)
# Actual Genres:  Drama
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Copycat (1995)
# Actual Genres:  Drama
# Pridicted as:   Crime|Drama|Mystery|Thriller
# movie_name:  Powder (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Sci-Fi
# movie_name:  Leaving Las Vegas (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Casino (1995)
# Actual Genres:  Drama
# Pridicted as:   Crime|Drama
# movie_name:  Sense and Sensibility (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Romance
# movie_name:  Money Train (1995)
# Actual Genres:  Drama
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Copycat (1995)
# Actual Genres:  Drama
# Pridicted as:   Crime|Drama|Mystery|Thriller
# movie_name:  Powder (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Sci-Fi
# movie_name:  Leaving Las Vegas (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Romance
# movie_name:  Toy Story (1995)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Balto (1995)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children
# movie_name:  Pocahontas (1995)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Drama|Musical|Romance
# movie_name:  Goofy Movie, A (1995)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Comedy|Romance
# movie_name:  Swan Princess, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children
# movie_name:  Lion King, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Drama
# movie_name:  Nightmare Before Christmas, The (1993)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Fantasy|Musical
# movie_name:  Pagemaster, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Action|Adventure|Animation|Children
# movie_name:  Aladdin (1992)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  Snow White and the Seven Dwarfs (1937)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Fantasy|Musical
# movie_name:  Super Mario Bros. (1993)
# Actual Genres:  Action|Adventure|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Children|Comedy|Fantasy
# movie_name:  Who Am I? (Wo shi shei) (1998)
# Actual Genres:  Action|Adventure|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Sci-Fi|Thriller
# movie_name:  Chicken Little (2005)
# Actual Genres:  Action|Adventure|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Sci-Fi
# movie_name:  Meet the Robinsons (2007)
# Actual Genres:  Action|Adventure|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Sci-Fi
# movie_name:  Aqua Teen Hunger Force Colon Movie Film for Theaters (2007)
# Actual Genres:  Action|Adventure|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Fantasy|Sci-Fi
# movie_name:  Chicken Little (2005)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Sci-Fi
# movie_name:  Meet the Robinsons (2007)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Sci-Fi
# movie_name:  Aqua Teen Hunger Force Colon Movie Film for Theaters (2007)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Fantasy|Sci-Fi
# movie_name:  Futurama: Bender's Game (2008)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Fantasy|Sci-Fi
# movie_name:  Megamind (2010)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Sci-Fi|IMAX
# movie_name:  Mars Needs Moms (2011)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Sci-Fi
# movie_name:  The Amazing Screw-On Head (2006)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Comedy|Sci-Fi
# movie_name:  Ratchet & Clank (2016)
# Actual Genres:  Action|Animation|Comedy|Sci-Fi
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Sci-Fi
# movie_name:  Pocahontas (1995)
# Actual Genres:  Animation|Drama
# Pridicted as:   Animation|Children|Drama|Musical|Romance
# movie_name:  Lion King, The (1994)
# Actual Genres:  Animation|Drama
# Pridicted as:   Adventure|Animation|Children|Drama
# movie_name:  Snow White and the Seven Dwarfs (1937)
# Actual Genres:  Animation|Drama
# Pridicted as:   Animation|Children|Fantasy|Musical
# movie_name:  Hunchback of Notre Dame, The (1996)
# Actual Genres:  Animation|Drama
# Pridicted as:   Animation|Children|Drama|Musical|Romance
# movie_name:  Dumbo (1941)
# Actual Genres:  Animation|Drama
# Pridicted as:   Animation|Children|Musical
# movie_name:  Fox and the Hound, The (1981)
# Actual Genres:  Animation|Drama
# Pridicted as:   Animation|Children|Drama
# movie_name:  Lesson Faust (1994)
# Actual Genres:  Animation|Drama
# Pridicted as:   Animation|Comedy|Drama|Fantasy
# movie_name:  Anastasia (1997)
# Actual Genres:  Animation|Drama
# Pridicted as:   Adventure|Animation|Children|Musical
# movie_name:  Mulan (1998)
# Actual Genres:  Animation|Drama
# Pridicted as:   Adventure|Animation|Children|Comedy|Drama|Musical|Romance
# movie_name:  Bambi (1942)
# Actual Genres:  Animation|Drama
# Pridicted as:   Animation|Children|Drama
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Comedy|Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Comedy|Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Money Train (1995)
# Actual Genres:  Comedy|Drama
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  To Die For (1995)
# Actual Genres:  Comedy|Drama
# Pridicted as:   Comedy|Drama|Thriller
# movie_name:  Mighty Aphrodite (1995)
# Actual Genres:  Comedy|Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Postman, The (Postino, Il) (1994)
# Actual Genres:  Comedy|Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Beautiful Girls (1996)
# Actual Genres:  Comedy|Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Toy Story (1995)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Balto (1995)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children
# movie_name:  Pocahontas (1995)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Drama|Musical|Romance
# movie_name:  Goofy Movie, A (1995)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Comedy|Romance
# movie_name:  Swan Princess, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children
# movie_name:  Lion King, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Drama
# movie_name:  Nightmare Before Christmas, The (1993)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Fantasy|Musical
# movie_name:  Pagemaster, The (1994)
# Actual Genres:  Animation
# Pridicted as:   Action|Adventure|Animation|Children
# movie_name:  Aladdin (1992)
# Actual Genres:  Animation
# Pridicted as:   Adventure|Animation|Children|Comedy|Musical
# movie_name:  Snow White and the Seven Dwarfs (1937)
# Actual Genres:  Animation
# Pridicted as:   Animation|Children|Fantasy|Musical
# movie_name:  Twelve Tasks of Asterix, The (Les douze travaux d'AstÃ©rix) (1976)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  TMNT (Teenage Mutant Ninja Turtles) (2007)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Aqua Teen Hunger Force Colon Movie Film for Theaters (2007)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Action|Adventure|Animation|Fantasy|Sci-Fi
# movie_name:  Futurama: Bender's Game (2008)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Action|Adventure|Animation|Fantasy|Sci-Fi
# movie_name:  The Lego Movie (2014)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Black Butler: Book of the Atlantic (2017)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Animation|Comedy|Fantasy
# movie_name:  Toy Story (1995)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Mask, The (1994)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Action|Comedy|Crime
# movie_name:  Last Action Hero (1993)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Action|Adventure|Comedy|Fantasy
# movie_name:  Super Mario Bros. (1993)
# Actual Genres:  Action|Animation|Comedy|Fantasy
# Pridicted as:   Action|Adventure|Children|Comedy|Fantasy
# movie_name:  Toy Story (1995)
# Actual Genres:  Animation|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Space Jam (1996)
# Actual Genres:  Animation|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Aladdin and the King of Thieves (1996)
# Actual Genres:  Animation|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy|Musical|Romance
# movie_name:  Lesson Faust (1994)
# Actual Genres:  Animation|Comedy|Fantasy
# Pridicted as:   Animation|Comedy|Drama|Fantasy
# movie_name:  All Dogs Go to Heaven (1989)
# Actual Genres:  Animation|Comedy|Fantasy
# Pridicted as:   Animation|Children|Comedy|Fantasy
# movie_name:  Antz (1998)
# Actual Genres:  Animation|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Yellow Submarine (1968)
# Actual Genres:  Animation|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Comedy|Fantasy
# movie_name:  Who Framed Roger Rabbit? (1988)
# Actual Genres:  Animation|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Toy Story 2 (1999)
# Actual Genres:  Animation|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Adventures of Rocky and Bullwinkle, The (2000)
# Actual Genres:  Animation|Comedy|Fantasy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Drama
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Casino (1995)
# Actual Genres:  Drama
# Pridicted as:   Crime|Drama
# movie_name:  Sense and Sensibility (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Romance
# movie_name:  Money Train (1995)
# Actual Genres:  Drama
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Copycat (1995)
# Actual Genres:  Drama
# Pridicted as:   Crime|Drama|Mystery|Thriller
# movie_name:  Powder (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Sci-Fi
# movie_name:  Leaving Las Vegas (1995)
# Actual Genres:  Drama
# Pridicted as:   Drama|Romance
# movie_name:  Pagemaster, The (1994)
# Actual Genres:  Action|Animation
# Pridicted as:   Action|Adventure|Animation|Children
# movie_name:  Heavy Metal (1981)
# Actual Genres:  Action|Animation
# Pridicted as:   Action|Adventure|Animation|Sci-Fi
# movie_name:  Akira (1988)
# Actual Genres:  Action|Animation
# Pridicted as:   Action|Adventure|Animation|Sci-Fi
# movie_name:  Great Mouse Detective, The (1986)
# Actual Genres:  Action|Animation
# Pridicted as:   Action|Animation|Children|Crime
# movie_name:  Princess Mononoke (Mononoke-hime) (1997)
# Actual Genres:  Action|Animation
# Pridicted as:   Action|Adventure|Animation|Drama|Fantasy
# movie_name:  Titan A.E. (2000)
# Actual Genres:  Action|Animation
# Pridicted as:   Action|Adventure|Animation|Children|Comedy|Sci-Fi
# movie_name:  Osmosis Jones (2001)
# Actual Genres:  Action|Animation
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# movie_name:  Spriggan (Supurigan) (1998)
# Actual Genres:  Action|Animation
# Pridicted as:   Action|Animation|Sci-Fi
# movie_name:  Escaflowne: The Movie (Escaflowne) (2000)
# Actual Genres:  Action|Animation
# Pridicted as:   Action|Adventure|Animation|Drama|Fantasy
# movie_name:  Powerpuff Girls, The (2002)
# Actual Genres:  Action|Animation
# Pridicted as:   Action|Animation|Children|Comedy
# movie_name:  Toy Story (1995)
# Actual Genres:  Comedy
# Pridicted as:   Adventure|Animation|Children|Comedy|Fantasy
# movie_name:  Grumpier Old Men (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  Waiting to Exhale (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Sabrina (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Romance
# movie_name:  American President, The (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Drama|Romance
# movie_name:  Dracula: Dead and Loving It (1995)
# Actual Genres:  Comedy
# Pridicted as:   Comedy|Horror
# movie_name:  Money Train (1995)
# Actual Genres:  Comedy
# Pridicted as:   Action|Comedy|Crime|Drama|Thriller
# Hit:0.3346027509751591
# Fault:0.6653972490248409
